# %% [markdown]
# # The example of tropical rainfall diagnostic during the streaming mode

# %% [markdown]
# ### Content

# %% [markdown]
# 1. [The load of packages, modules, and data](#1-load-of-packages-modules-and-data)
#
# 2. [Calculating and saving the histograms in the storage for each stream output](#2-calculating-and-saving-to-the-memory-the-histograms-for-each-stream-output-ten-in-total)
#
# 3. [Loading and merging all the histograms from the specified repository](#3-loading-and-merging-all-the-histograms-in-the-specified-repository)
#
# 4. [Loading and merging multiple histograms from the specified repository ](#4-loading-and-merging-multiple-histograms-in-the-specified-repository)

# %% [markdown]
# ## 1. The load of packages, modules, and data

# %%
from aqua import Reader
from tropical_rainfall import Tropical_Rainfall

# %% [markdown]
# ##### You can initialize the diagnostic in the way you prefer. The demonstration of different initializations of diagnostic you can find in the notebook ``ICON_histogram_calculation.ipynb``

# %%
diag = Tropical_Rainfall()

# %%
reader = Reader(model="ICON", exp="historical-1990", source="lra-r100-monthly", streaming=True, aggregation="M")
# Out:
# 2024-04-16 21:08:02 :: Reader :: WARNING  -> LRA_LUMI parameter is required but is missing, setting to default /work/bb1153/b382076/LRA-lumi

# %% [markdown]
# ## 2. Calculating and saving the histograms in the storage for each stream output

# %% [markdown]
# ##### Set the path to the repository where you would like to store the histograms.

# %%
diag.path_to_histograms='/work/bb1153/b382267/tropical_rainfall_cicle3/demo/' # Please specify path to the histograms

# %%
name_of_file='icon'

# %% [markdown]
# ##### `Note`: the diagnostic already provides unique names for the histograms. Namely, the name of the histogram includes the starting and final time steps for which the diagnostic performs the calculations in the following format: `year-month-day-hour`. The name of the file, which you specified, would be added at the beginning of the file name.
#
# ##### For example, for the first output, the name of the histogram is `icon_2020-01-20T00_2020-01-20T23_histogram.pkl`.

# %% [markdown]
# ##### Calculating the histograms and storing them in the memory:

# %%
for i in range(0, 5):
    icon_chunk = reader.retrieve() 

    hist_icon  = diag.histogram(icon_chunk)
    diag.dataset_to_netcdf(dataset = hist_icon, path_to_netcdf = diag.path_to_histograms, 
                           name_of_file = name_of_file)
# Out:
# 2024-04-16 21:08:24 :: frequency_string_to_pandas :: WARNING  -> You are using a pandas frequency pointing at the end of a period, this can behave unexpectedly if you have subdaily data
# 2024-04-16 21:08:28 :: frequency_string_to_pandas :: WARNING  -> You are using a pandas frequency pointing at the end of a period, this can behave unexpectedly if you have subdaily data
# 2024-04-16 21:08:33 :: frequency_string_to_pandas :: WARNING  -> You are using a pandas frequency pointing at the end of a period, this can behave unexpectedly if you have subdaily data
# 2024-04-16 21:08:37 :: frequency_string_to_pandas :: WARNING  -> You are using a pandas frequency pointing at the end of a period, this can behave unexpectedly if you have subdaily data
# 2024-04-16 21:08:42 :: frequency_string_to_pandas :: WARNING  -> You are using a pandas frequency pointing at the end of a period, this can behave unexpectedly if you have subdaily data

# %% [markdown]
# ## 3. Loading and merging all the histograms from the specified repository

# %% [markdown]
# ##### If you want to merge all histograms if the specified repository, set the following flag: `all=True.`
#
# ##### The function will merge all histograms into single histograms. In order to avoid possible mistakes, keep the histograms obtained for different models in different repositories.

# %%
diag.path_to_histograms
# Out:
# '/work/bb1153/b382267/tropical_rainfall_cicle3/demo/'

# %%
merged_histograms = diag.merge_list_of_histograms(path_to_histograms=diag.path_to_histograms)
merged_histograms
# Out:
# <xarray.Dataset> Size: 240kB
# Dimensions:        (center_of_bin: 5000)
# Coordinates:
#   * center_of_bin  (center_of_bin) float64 40kB 0.25 0.75 ... 2.499e+03 2.5e+03
#     width          (center_of_bin) float64 40kB 0.5 0.5 0.5 0.5 ... 0.5 0.5 0.5
# Data variables:
#     counts         (center_of_bin) float64 40kB 1.209e+04 4.815e+03 ... 0.0 0.0
#     frequency      (center_of_bin) float64 40kB 0.1866 0.07431 ... 0.0 0.0
#     pdf            (center_of_bin) float64 40kB 0.3732 0.1486 0.1093 ... 0.0 0.0
#     pdfP           (center_of_bin) float64 40kB ...
# Attributes:
#     history:                \n2024-04-16 21:04:47 AQUA💧: Retrieved from ICON_...
#     time_band:              1990-01-01T00:00:00.000000000, 1990-06-01T00:00:0...
#     lat_band:               -14.5, 14.5, freq=1.0
#     lon_band:               0.0, 359.0, freq=1.0
#     time_band_history:      1990-01-01T00:00:00.000000000; 1990-02-01T00:00:0...
#     units:                  mm/day
#     mean_of_original_data:  5.543671558181305; 5.205667541329904; 5.283338023...
#     mean_of_histogram:      5.564259259259259; 5.231805555555557; 5.302407407...
#     relative_discrepancy:   -0.3713730307050868; -0.5021068675272251; -0.3609...

# %% [markdown]
# ## 4. Loading and merging multiple histograms from the specified repository

# %% [markdown]
# ##### If you want to merge only a specific number of histograms, set the function `start_year`, `end_year`, `start_month` and
#  `end_month` arguments.
# ##### Note: The function will sort the files in the repository and merge the histograms that satisfy the specified time range.

# %%
merged_histograms = diag.merge_list_of_histograms(path_to_histograms=diag.path_to_histograms, start_month=2, end_month=4)
merged_histograms
# Out:
# <xarray.Dataset>
# Dimensions:        (center_of_bin: 20)
# Coordinates:
#   * center_of_bin  (center_of_bin) float64 3.333e-08 1e-07 ... 1.233e-06 1.3e-06
#     width          (center_of_bin) float64 6.667e-08 6.667e-08 ... 6.667e-08
# Data variables:
#     counts         (center_of_bin) float64 1.353e+06 7.791e+04 ... 8.054e+03
#     frequency      (center_of_bin) float64 0.7761 0.04471 ... 0.004772 0.004621
#     pdf            (center_of_bin) float64 1.164e+07 6.706e+05 ... 6.932e+04
# Attributes:
#     CDI:                  Climate Data Interface version 1.8.3rc (http://mpim...
#     Conventions:          CF-1.6
#     comment:              Sapphire Dyamond (k203123) on l40687 (Linux 4.18.0-...
#     grid_file_uri:        http://icon-downloads.mpimet.mpg.de/grids/public/mp...
#     history:              ./icon at 20220512 1522142023-07-11 13:19:11 regrid...
#     institution:          Max Planck Institute for Meteorology/Deutscher Wett...
#     number_of_grid_used:  15
#     references:           see MPIM/DWD publications
#     source:               git@gitlab.dkrz.de:icon/icon-aes.git@87a1eaded69e87...
#     title:                ICON simulation
#     uuidOfHGrid:          0f1e7d66-637e-11e8-913b-51232bb4d8f9
