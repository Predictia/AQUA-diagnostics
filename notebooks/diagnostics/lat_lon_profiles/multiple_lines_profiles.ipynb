# %% [markdown]
# # LatLonProfiles diagnostic - Multiple lines profiles
#
# The aim of this diagnostic is to visualise latitudinal or longitudinal profiles of a certain variable. In addition, plots are allowed to have multiple lines and/or show the seasonal and annual means of the selected variable.
#
# Specifically, in this notebook we look at the code for example plots of a multiple lines zonal profiles (along with the reference data).

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start with the import of the classes `LatLonProfiles` and `PlotLatLonProfiles`:

# %%
from aqua.diagnostics.lat_lon_profiles import LatLonProfiles
from aqua.diagnostics.lat_lon_profiles import PlotLatLonProfiles
# Out:
# /LUMI_TYKKY_IZ4yJl9/miniforge/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# We generate a number of dictionaries, `dataset_dict`, including the options for the data we want to plot in this notebook.
# A reference profile to be plotted along with the input dataset is optional. If chosen, `obs_dict` is necessary.
# Lastly, the dictionaries `common_dict` include the common features for both datasets (input and reference) in case of historical data and in case of future scenarios, such as start and end dates.
#
# In this notebook, we will look at climate model outputs coming from both ICON and IFS-NEMO, and from 1990 to 1999 (historical) and 2030-2039 (future scenarios)
#
# Dictionaries also contain the optional `region` parameter, to select a specific area of interest. List of available default regions are Tropics, Europe, North Midlatitudes (from 30 to 90 N) and South Midlatitudes.

# %%
dataset_dict_1 = {'catalog': 'climatedt-phase1',
                'model': 'ICON',
                'exp': 'historical-1990',
                'source': 'lra-r100-monthly'}

dataset_dict_2 = {'catalog': 'climatedt-phase1',
                  'model': 'ICON',
                  'exp': 'ssp370',
                  'source': 'lra-r100-monthly'}

dataset_dict_3 = {'catalog': 'climatedt-phase1',
                  'model': 'IFS-NEMO',
                  'exp': 'historical-1990',
                  'source': 'lra-r100-monthly'}

dataset_dict_4 = {'catalog': 'climatedt-phase1',
                  'model': 'IFS-NEMO',
                  'exp': 'ssp370',
                  'source': 'lra-r100-monthly'}

common_dict_hist = {'startdate': '1990-01-01',
               'enddate': '1999-12-31',
               'region': 'tropics',
               'loglevel': 'info'}

common_dict_ssp = {'startdate': '2030-01-01',
                   'enddate': '2039-12-31',
                   'region': 'tropics',
                   'loglevel': 'info'}

obs_dict = {'catalog': 'obs',
            'model': 'ERA5',
            'exp': 'era5',
            'source': 'monthly',
            'std_startdate': '1990-01-01',
            'std_enddate': '1999-12-31'}

# %% [markdown]
# We hence generate an object of the `LatLonProfiles` class for each line, and we decide to plot zonal profiles as an example. This means that the code will be performing the zonal mean, by averaging across the longitudes.
#
# The analysed variable for this notebook will be `tprate` (Total Precipitation Rate, expressed in mm/day).
#
# By default, the `mean_type` parameter in set as 'zonal' (so the profile will be zonal even without a specific `mean_type` setting), but to visualise the meridional profile, one can just set `mean_type='meridional'`. We also generate another LatLonProfiles object for the reference zonal profile.
#
# The `std=True` option computes the standard deviation and is optional. We set it as `True` for the ERA5 reference profile to enable uncertainty shading in plots via `ref_std_data`. While model data can also compute std, only reference std shading is directly supported for plotting simplicity.

# %%
lonlat_dataset_1 = LatLonProfiles(**dataset_dict_1, **common_dict_hist, mean_type='zonal')
lonlat_dataset_2 = LatLonProfiles(**dataset_dict_2, **common_dict_ssp)
lonlat_dataset_3 = LatLonProfiles(**dataset_dict_3, **common_dict_hist)
lonlat_dataset_4 = LatLonProfiles(**dataset_dict_4, **common_dict_ssp)

lonlat_obs = LatLonProfiles(**obs_dict, **common_dict_hist, mean_type='zonal')

run_dict = {'var': 'tprate',
            'units': 'mm/day'}

lonlat_dataset_1.run(**run_dict)
lonlat_dataset_2.run(**run_dict)
lonlat_dataset_3.run(**run_dict)
lonlat_dataset_4.run(**run_dict)

lonlat_obs.run(**run_dict, std=True)
# Out:
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-11-07 14:51:52 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-11-07 14:51:52 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-11-07 14:51:52 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-11-07 14:51:52 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-11-07 14:51:52 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-11-07 14:51:52 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-11-07 14:51:52 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-11-07 14:51:52 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-11-07 14:52:08 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:52:08 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-11-07 14:52:08 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:52:08 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-11-07 14:52:08 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-11-07 14:52:08 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:52:08 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-11-07 14:52:08 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-11-07 14:52:08 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-11-07 14:52:09 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:52:09 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:52:09 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:52:09 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-11-07 14:52:09 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2025-11-07 14:52:09 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:52:09 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.seasonal.djf.tprate.tropics.nc
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2025-11-07 14:52:09 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:52:09 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.seasonal.mam.tprate.tropics.nc
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2025-11-07 14:52:09 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:52:09 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.seasonal.jja.tprate.tropics.nc
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2025-11-07 14:52:09 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:52:09 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.seasonal.son.tprate.tropics.nc
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:52:09 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-11-07 14:52:09 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2025-11-07 14:52:09 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:52:09 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.longterm.tprate.tropics.nc
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-11-07 14:52:09 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-11-07 14:52:10 :: ConfigPath :: INFO     -> ICON_ssp370_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-11-07 14:52:10 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-11-07 14:52:10 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-11-07 14:52:10 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-11-07 14:52:10 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-11-07 14:52:10 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-11-07 14:52:10 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-11-07 14:53:06 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-11-07 14:53:06 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:53:06 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-11-07 14:53:06 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:53:06 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-11-07 14:53:06 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-11-07 14:53:06 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_ssp370_lra-r100-monthly.nc.
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-11-07 14:53:06 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-11-07 14:53:06 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-11-07 14:53:06 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:53:06 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:53:07 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:53:07 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-11-07 14:53:07 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:07 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:07 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.ssp370.r1.seasonal.djf.tprate.tropics.nc
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:07 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:07 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.ssp370.r1.seasonal.mam.tprate.tropics.nc
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:07 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:07 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.ssp370.r1.seasonal.jja.tprate.tropics.nc
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:07 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:07 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.ssp370.r1.seasonal.son.tprate.tropics.nc
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:53:07 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:53:07 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-11-07 14:53:07 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:53:08 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-11-07 14:53:08 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:08 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:08 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.ICON.ssp370.r1.longterm.tprate.tropics.nc
# 2025-11-07 14:53:08 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2025-11-07 14:53:08 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-11-07 14:53:08 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-11-07 14:53:08 :: ConfigPath :: INFO     -> IFS-NEMO_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-11-07 14:53:08 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-11-07 14:53:08 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-11-07 14:53:08 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-11-07 14:53:08 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-11-07 14:53:08 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-11-07 14:53:41 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-11-07 14:53:41 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:53:41 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-11-07 14:53:41 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-11-07 14:53:41 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-11-07 14:53:41 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-11-07 14:53:41 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_IFS-NEMO_historical-1990_lra-r100-monthly.nc.
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:53:41 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-11-07 14:53:41 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-11-07 14:53:41 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-11-07 14:53:41 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:53:42 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:53:42 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:53:42 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-11-07 14:53:42 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:42 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:42 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.historical-1990.r1.seasonal.djf.tprate.tropics.nc
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:42 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:42 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.historical-1990.r1.seasonal.mam.tprate.tropics.nc
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:42 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:42 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.historical-1990.r1.seasonal.jja.tprate.tropics.nc
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:42 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:42 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.historical-1990.r1.seasonal.son.tprate.tropics.nc
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:53:42 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:53:42 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-11-07 14:53:42 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:53:43 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-11-07 14:53:43 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2025-11-07 14:53:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:53:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.historical-1990.r1.longterm.tprate.tropics.nc
# 2025-11-07 14:53:43 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2025-11-07 14:53:43 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-11-07 14:53:43 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-11-07 14:53:43 :: ConfigPath :: INFO     -> IFS-NEMO_ssp370_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-11-07 14:53:43 :: Reader :: INFO     -> realization parameter is required but is missing, setting to default r1
# 2025-11-07 14:53:43 :: Reader :: INFO     -> Available values for realization are: ['r1']
# 2025-11-07 14:53:43 :: Reader :: INFO     -> region parameter is required but is missing, setting to default global
# 2025-11-07 14:53:43 :: Reader :: INFO     -> Available values for region are: ['global']
# 2025-11-07 14:53:43 :: Reader :: INFO     -> stat parameter is required but is missing, setting to default mean
# 2025-11-07 14:53:43 :: Reader :: INFO     -> Available values for stat are: ['mean']
# 2025-11-07 14:53:43 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-11-07 14:53:43 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-11-07 14:53:44 :: Reader :: INFO     -> Grid metadata is lon-lat-r100
# 2025-11-07 14:53:44 :: Regridder :: INFO     -> Grid name: lon-lat-r100
# 2025-11-07 14:53:44 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_lon-lat-r100.nc.
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:53:44 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-11-07 14:53:44 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-11-07 14:54:35 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-11-07 14:54:35 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:54:35 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:54:35 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:35 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-11-07 14:54:35 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.ssp370.r1.seasonal.djf.tprate.tropics.nc
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.ssp370.r1.seasonal.mam.tprate.tropics.nc
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.ssp370.r1.seasonal.jja.tprate.tropics.nc
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.ssp370.r1.seasonal.son.tprate.tropics.nc
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:54:35 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:54:35 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-11-07 14:54:35 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:36 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-11-07 14:54:36 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-phase1.IFS-NEMO.ssp370.r1.longterm.tprate.tropics.nc
# 2025-11-07 14:54:36 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2025-11-07 14:54:36 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-11-07 14:54:36 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-11-07 14:54:36 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-11-07 14:54:37 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-11-07 14:54:37 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-11-07 14:54:37 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-11-07 14:54:37 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-11-07 14:54:37 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-11-07 14:54:37 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:54:37 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-11-07 14:54:37 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-11-07 14:54:37 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2025-11-07 14:54:37 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-11-07 14:54:38 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-11-07 14:54:38 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-11-07 14:54:38 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-11-07 14:54:38 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:54:38 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-11-07 14:54:38 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:38 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-11-07 14:54:38 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-11-07 14:54:39 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-11-07 14:54:39 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-11-07 14:54:39 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:40 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-11-07 14:54:40 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-11-07 14:54:40 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# /LUMI_TYKKY_IZ4yJl9/miniforge/envs/env1/lib/python3.12/site-packages/dask/array/numpy_compat.py:58: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.tprate.tropics.nc
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.tprate.tropics.nc
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.tprate.tropics.nc
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.tprate.tropics.nc
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.std.tprate.tropics.nc
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.std.tprate.tropics.nc
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.std.tprate.tropics.nc
# 2025-11-07 14:54:43 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:43 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.std.tprate.tropics.nc
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:54:43 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-11-07 14:54:43 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-11-07 14:54:43 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:46 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-11-07 14:54:46 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-11-07 14:54:46 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-11-07 14:54:46 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-11-07 14:54:47 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-11-07 14:54:47 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# /LUMI_TYKKY_IZ4yJl9/miniforge/envs/env1/lib/python3.12/site-packages/dask/array/numpy_compat.py:58: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# 2025-11-07 14:54:50 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-11-07 14:54:50 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2025-11-07 14:54:50 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:50 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.tprate.tropics.nc
# 2025-11-07 14:54:50 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-11-07 14:54:50 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.annual.std.tprate.tropics.nc
# 2025-11-07 14:54:50 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed

# %% [markdown]
# Different types of dataset can be managed and plotted via `LatLonProfiles` and `PlotLatLonProfiles`:
# - Seasonal mean, with season choice between DJF, MAM, JJA and SON
# - Annual mean
#
# ## Single plot - Seasonal means
#
# LatLonProfiles objects include the seasonal mean for each season. For this example, we plot the winter DJF means (selected via the [0] option), along with the winter ERA5 reference data as well as the standard deviation shadings.
#
# Standard deviation shading is enabled for the ERA5 reference data via `ref_std_data`, providing uncertainty bands that aid in model validation. The plotting code follows:

# %%
# Use seasonal data (DJF - winter as example)
multi_line_plot = PlotLatLonProfiles(
    data=[lonlat_dataset_1.seasonal[0],        # ICON tprate - DJF 1990-1999
          lonlat_dataset_2.seasonal[0],        # ICON tprate - DJF 2030-2039
          lonlat_dataset_3.seasonal[0],        # IFS-NEMO tprate - DJF 1990-1999
          lonlat_dataset_4.seasonal[0]],       # IFS-NEMO tprate - DJF 2030-2039
    ref_data=lonlat_obs.seasonal[0],  # ERA5 Reference tprate - DJF 1990-1999
    data_type='longterm',
    ref_std_data=lonlat_obs.std_seasonal[0],  # DJF std for ERA5 Reference tprate
    loglevel='INFO'
)

title = "DJF Total precipitation rate comparison in the past and in the future for CMIP6 models"
multi_line_plot.run()
# Out:
# 2025-11-07 14:54:50 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2025-11-07 14:54:50 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-11-07 14:54:51 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:51 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:51 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# We hence use the PlotLatLonProfiles class to finalise the example plots, starting from the annual means and concluding with the seasonal means.
#
# ## Single plot - Annual means
#
# The logic is the same as the previous plot, only changing the `.seasonal` object with `.longterm`:

# %%
# Create separate annual plot for multi-data
annual_multi_data = [
    lonlat_dataset_1.longterm,        # ICON tprate - 1990-1999
    lonlat_dataset_2.longterm,        # ICON tprate - 2030-2039
    lonlat_dataset_3.longterm,        # IFS-NEMO tprate - 1990-1999
    lonlat_dataset_4.longterm,        # IFS-NEMO tprate - 2030-2039
]

annual_multi_plot = PlotLatLonProfiles(
    data=annual_multi_data,
    ref_data=lonlat_obs.longterm,
    data_type='longterm',
    ref_std_data=lonlat_obs.std_annual,  # Annual std for ERA5 Reference tprate
    loglevel='INFO'
)

# Run the annual multi plot
annual_multi_plot.run()
# Out:
# 2025-11-07 14:54:51 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2025-11-07 14:54:51 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-11-07 14:54:52 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:52 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:52 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# ## Multiple plot - Seasonal mean profiles
#
# As for the annual mean plot, same logic applies also for seasonal profiles:

# %%
# Prepare model data for 4 seasons
combined_seasonal_model_data = []
combined_seasonal_ref_data = []

for i in range(4):  # DJF, MAM, JJA, SON
    combined_seasonal_model_data.append([
        lonlat_dataset_1.seasonal[i],    # ICON tprate - 1990-1999 - season i
        lonlat_dataset_2.seasonal[i],    # ICON tprate - 2030-2039 - season i
        lonlat_dataset_3.seasonal[i],    # IFS-NEMO tprate - 1990-1999 - season i
        lonlat_dataset_4.seasonal[i],    # IFS-NEMO tprate - 2030-2039 - season i
    ])
    combined_seasonal_ref_data.append(lonlat_obs.seasonal[i])

# Prepare std data for reference only
multi_ref_std_data = [lonlat_obs.std_seasonal[i] for i in range(4)]

# Create 4-panel seasonal plot with multiple variables
seasonal_multi_plot = PlotLatLonProfiles(
    data=combined_seasonal_model_data,
    ref_data=combined_seasonal_ref_data, 
    ref_std_data=multi_ref_std_data,
    data_type='seasonal',
    loglevel='INFO'
)

# Run the seasonal plot (multi_var_labels is already defined in the previous cell)
seasonal_multi_plot.run()
# Out:
# 2025-11-07 14:54:52 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# /pfs/lustrep3/users/cadaumar/AQUA/src/aqua/graphics/seasonal_means.py:111: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# 2025-11-07 14:54:53 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-11-07 14:54:53 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/lat_lon_profiles.seasonal_zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:53 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.seasonal_zonal_profile.climatedt-phase1.ICON.historical-1990.r1.tprate.tropics.png
# 2025-11-07 14:54:53 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully
