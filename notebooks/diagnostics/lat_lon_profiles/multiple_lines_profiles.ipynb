# %% [markdown]
# # LatLonProfiles diagnostic - Multiple lines profiles
#
# The aim of this diagnostic is to visualise latitudinal or longitudinal profiles of a certain variable. In addition, plots are allowed to have multiple lines and/or show the seasonal and annual means of the selected variable.
#
# Specifically, in this notebook we look at the code for example plots of a multiple lines zonal profiles (along with the reference data).

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start with the import of the classes `LatLonProfiles` and `PlotLatLonProfiles`:

# %%
from aqua.diagnostics.lat_lon_profiles import LatLonProfiles, PlotLatLonProfiles

# %% [markdown]
# We generate a number of dictionaries, `dataset_dict`, including the options for the data we want to plot in this notebook.
# A reference profile to be plotted along with the input dataset is optional. If chosen, `obs_dict` is necessary.
# Lastly, the dictionaries `common_dict` include the common features for both datasets (input and reference) in case of historical data and in case of future scenarios, such as start and end dates.
#
# In this notebook, we will look at climate model outputs coming from both ICON and IFS-NEMO, and from 1990 to 1999 (historical) and 2030-2039 (future scenarios)
#
# Dictionaries also contain the optional `region` parameter, to select a specific area of interest. List of available default regions are Tropics, Europe, North Midlatitudes (from 30 to 90 N) and South Midlatitudes.

# %%
dataset_dict_1 = {"catalog": "climatedt-gen2", "model": "ICON-5km", "exp": "baseline-hist", "source": "lra-r100-monthly"}

dataset_dict_2 = {"catalog": "climatedt-gen2", "model": "ICON-5km", "exp": "projections-ssp370", "source": "lra-r100-monthly"}

dataset_dict_3 = {"catalog": "climatedt-gen2", "model": "IFS-FESOM-5km", "exp": "baseline-hist", "source": "lra-r100-monthly"}

dataset_dict_4 = {
    "catalog": "climatedt-gen2",
    "model": "IFS-FESOM-5km",
    "exp": "projections-ssp370",
    "source": "lra-r100-monthly",
}

common_dict_hist = {"startdate": "1990-01-01", "enddate": "1999-12-31", "region": "tropics", "loglevel": "info"}

common_dict_ssp = {"startdate": "2030-01-01", "enddate": "2039-12-31", "region": "tropics", "loglevel": "info"}

obs_dict = {
    "catalog": "obs",
    "model": "ERA5",
    "exp": "era5",
    "source": "monthly",
    "std_startdate": "1990-01-01",
    "std_enddate": "1999-12-31",
}

# %% [markdown]
# We hence generate an object of the `LatLonProfiles` class for each line, and we decide to plot zonal profiles as an example. This means that the code will be performing the zonal mean, by averaging across the longitudes.
#
# The analysed variable for this notebook will be `tprate` (Total Precipitation Rate, expressed in mm/day).
#
# By default, the `mean_type` parameter in set as 'zonal' (so the profile will be zonal even without a specific `mean_type` setting), but to visualise the meridional profile, one can just set `mean_type='meridional'`. We also generate another LatLonProfiles object for the reference zonal profile.
#
# The `std=True` option computes the standard deviation and is optional. We set it as `True` for the ERA5 reference profile to enable uncertainty shading in plots via `ref_std_data`. While model data can also compute std, only reference std shading is directly supported for plotting simplicity.

# %%
lonlat_dataset_1 = LatLonProfiles(**dataset_dict_1, **common_dict_hist, mean_type="zonal")
lonlat_dataset_2 = LatLonProfiles(**dataset_dict_2, **common_dict_ssp)
lonlat_dataset_3 = LatLonProfiles(**dataset_dict_3, **common_dict_hist)
lonlat_dataset_4 = LatLonProfiles(**dataset_dict_4, **common_dict_ssp)

lonlat_obs = LatLonProfiles(**obs_dict, **common_dict_hist, mean_type="zonal")

run_dict = {"var": "tprate", "units": "mm/day"}

lonlat_dataset_1.run(**run_dict)
lonlat_dataset_2.run(**run_dict)
lonlat_dataset_3.run(**run_dict)
lonlat_dataset_4.run(**run_dict)

lonlat_obs.run(**run_dict, std=True)
# Out:
# 2026-05-06 12:13:31 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2026-05-06 12:13:31 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2026-05-06 12:13:31 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2026-05-06 12:13:31 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2026-05-06 12:13:32 :: LatLonProfiles :: INFO     -> Region Tropics found, using lon: [-180, 180], lat: [-15, 15]
# 2026-05-06 12:13:32 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:13:32 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:13:32 :: ConfigPath :: INFO     -> ICON-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-05-06 12:13:32 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:13:32 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-05-06 12:13:32 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-05-06 12:13:32 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-05-06 12:13:32 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-05-06 12:14:32 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:14:32 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:14:32 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:14:32 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-05-06 12:14:32 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-05-06 12:14:32 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_ICON-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-05-06 12:14:32 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:14:32 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:14:32 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:14:32 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-05-06 12:14:33 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-05-06 12:14:33 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:14:33 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:14:33 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:14:33 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:14:33 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:14:33 :: timmean_chunking :: INFO     -> 39 chunks from 1990-03-01 00:00:00 to 1999-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:14:33 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:14:33 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.djf.tprate.tropics.nc
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:14:33 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:14:33 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.mam.tprate.tropics.nc
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:14:33 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:14:33 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.jja.tprate.tropics.nc
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:14:33 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:14:33 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.son.tprate.tropics.nc
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:14:33 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:14:33 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:14:33 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:14:34 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:14:34 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:14:34 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:14:34 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.longterm.tprate.tropics.nc
# 2026-05-06 12:14:34 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-05-06 12:14:34 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:14:34 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:14:34 :: ConfigPath :: INFO     -> ICON-5km_projections-ssp370_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-05-06 12:14:34 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:14:34 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-05-06 12:14:35 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-05-06 12:14:35 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-05-06 12:14:35 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-05-06 12:15:23 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:15:23 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:15:23 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:15:23 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:15:23 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-05-06 12:15:23 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-05-06 12:15:23 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_ICON-5km_projections-ssp370_lra-r100-monthly.nc.
# 2026-05-06 12:15:23 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:15:23 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:15:23 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-05-06 12:15:23 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-05-06 12:15:23 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:15:23 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Start date: 2030-01-01
# 2026-05-06 12:15:23 :: LatLonProfiles :: WARNING  -> Requested enddate 2039-12-31 not available; using 2036-12-01 instead.
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> End date: 2036-12-01
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:15:23 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:15:23 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:15:23 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:15:23 :: timmean_chunking :: INFO     -> 27 chunks from 2030-03-01 00:00:00 to 2036-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:15:23 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:15:23 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.djf.tprate.tropics.nc
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:15:23 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:15:23 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.mam.tprate.tropics.nc
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:15:23 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:15:23 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.jja.tprate.tropics.nc
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:15:23 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:15:23 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.son.tprate.tropics.nc
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:15:23 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:15:23 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:15:23 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:15:24 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:15:24 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:15:24 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:15:24 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.longterm.tprate.tropics.nc
# 2026-05-06 12:15:24 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-05-06 12:15:24 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:15:24 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:15:24 :: ConfigPath :: INFO     -> IFS-FESOM-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-05-06 12:15:24 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:15:24 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-05-06 12:15:24 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-05-06 12:15:24 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-05-06 12:15:24 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-05-06 12:16:00 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:16:00 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:16:00 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:16:00 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:16:00 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-05-06 12:16:00 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-05-06 12:16:00 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-05-06 12:16:00 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:16:00 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:16:00 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-05-06 12:16:00 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-05-06 12:16:00 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:16:00 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:16:00 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:16:00 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:16:00 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:16:01 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:16:01 :: timmean_chunking :: INFO     -> 39 chunks from 1990-03-01 00:00:00 to 1999-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:16:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:16:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.djf.tprate.tropics.nc
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:16:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:16:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.mam.tprate.tropics.nc
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:16:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:16:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.jja.tprate.tropics.nc
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:16:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:16:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.son.tprate.tropics.nc
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:16:01 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:16:01 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:16:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:16:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.longterm.tprate.tropics.nc
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:16:01 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:16:01 :: ConfigPath :: INFO     -> IFS-FESOM-5km_projections-ssp370_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-05-06 12:16:02 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:16:02 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-05-06 12:16:02 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-05-06 12:16:02 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-05-06 12:16:02 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-05-06 12:17:21 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:17:21 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:17:21 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:17:21 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:17:21 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-05-06 12:17:21 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-05-06 12:17:21 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_projections-ssp370_lra-r100-monthly.nc.
# 2026-05-06 12:17:21 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:17:21 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:17:21 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-05-06 12:17:21 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-05-06 12:17:21 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:17:21 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> Start date: 2030-01-01
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> End date: 2039-12-31
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:17:21 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:17:21 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:21 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:17:22 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:17:22 :: timmean_chunking :: INFO     -> 39 chunks from 2030-03-01 00:00:00 to 2039-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:22 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:22 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.djf.tprate.tropics.nc
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:22 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:22 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.mam.tprate.tropics.nc
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:22 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:22 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.jja.tprate.tropics.nc
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:22 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:22 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.son.tprate.tropics.nc
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:17:22 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:17:22 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:22 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:22 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.longterm.tprate.tropics.nc
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:17:22 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:17:22 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2026-05-06 12:17:23 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:17:23 :: FixerConfigure :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2026-05-06 12:17:23 :: FixerConfigure :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2026-05-06 12:17:23 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2026-05-06 12:17:23 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2026-05-06 12:17:23 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2026-05-06 12:17:23 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:17:23 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:17:23 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:17:25 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2026-05-06 12:17:25 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2026-05-06 12:17:25 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:17:25 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:17:25 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:17:25 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:25 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:17:25 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:17:25 :: timmean_chunking :: INFO     -> 39 chunks from 1990-03-01 00:00:00 to 1999-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:17:28 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:17:28 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:17:28 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:28 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:17:28 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:17:28 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 2026-05-06 12:17:32 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:17:32 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.tprate.tropics.nc
# 2026-05-06 12:17:32 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.tprate.tropics.nc
# 2026-05-06 12:17:32 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.tprate.tropics.nc
# 2026-05-06 12:17:32 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.tprate.tropics.nc
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.std.tprate.tropics.nc
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.std.tprate.tropics.nc
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.std.tprate.tropics.nc
# 2026-05-06 12:17:32 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:32 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.std.tprate.tropics.nc
# 2026-05-06 12:17:33 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:17:33 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:17:33 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:17:33 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:36 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:17:36 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:17:36 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:17:36 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:17:36 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:17:36 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 2026-05-06 12:17:40 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:17:40 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:17:40 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:41 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.tprate.tropics.nc
# 2026-05-06 12:17:41 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:17:41 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.std.tprate.tropics.nc
# 2026-05-06 12:17:41 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed

# %% [markdown]
# Different types of dataset can be managed and plotted via `LatLonProfiles` and `PlotLatLonProfiles`:
# - Seasonal mean, with season choice between DJF, MAM, JJA and SON
# - Annual mean
#
# ## Single plot - Seasonal means
#
# LatLonProfiles objects include the seasonal mean for each season. For this example, we plot the winter DJF means (selected via the [0] option), along with the winter ERA5 reference data as well as the standard deviation shadings.
#
# Standard deviation shading is enabled for the ERA5 reference data via `ref_std_data`, providing uncertainty bands that aid in model validation. The plotting code follows:

# %%
# Use seasonal data (DJF - winter as example)
multi_line_plot = PlotLatLonProfiles(
    data=[
        lonlat_dataset_1.seasonal[0],  # ICON tprate - DJF 1990-1999
        lonlat_dataset_2.seasonal[0],  # ICON tprate - DJF 2030-2039
        lonlat_dataset_3.seasonal[0],  # IFS-NEMO tprate - DJF 1990-1999
        lonlat_dataset_4.seasonal[0],
    ],  # IFS-NEMO tprate - DJF 2030-2039
    ref_data=lonlat_obs.seasonal[0],  # ERA5 Reference tprate - DJF 1990-1999
    data_type="longterm",
    ref_std_data=lonlat_obs.std_seasonal[0],  # DJF std for ERA5 Reference tprate
    loglevel="INFO",
)

title = "DJF Total precipitation rate comparison in the past and in the future for CMIP6 models"
multi_line_plot.run(show=True, format="png")
# Out:
# 2026-05-06 12:17:42 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-05-06 12:17:42 :: PlotLatLonProfiles :: INFO     -> Description: Climatological zonal profile of total precipitation rate over Tropics for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-05-06 12:17:42 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-05-06 12:17:42 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.tropics.png
# 2026-05-06 12:17:42 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# We hence use the PlotLatLonProfiles class to finalise the example plots, starting from the annual means and concluding with the seasonal means.
#
# ## Single plot - Annual means
#
# The logic is the same as the previous plot, only changing the `.seasonal` object with `.longterm`:

# %%
# Create separate annual plot for multi-data
annual_multi_data = [
    lonlat_dataset_1.longterm,  # ICON tprate - 1990-1999
    lonlat_dataset_2.longterm,  # ICON tprate - 2030-2039
    lonlat_dataset_3.longterm,  # IFS-NEMO tprate - 1990-1999
    lonlat_dataset_4.longterm,  # IFS-NEMO tprate - 2030-2039
]

annual_multi_plot = PlotLatLonProfiles(
    data=annual_multi_data,
    ref_data=lonlat_obs.longterm,
    data_type="longterm",
    ref_std_data=lonlat_obs.std_annual,  # Annual std for ERA5 Reference tprate
    loglevel="INFO",
)

# Run the annual multi plot
annual_multi_plot.run(show=True, format="png")
# Out:
# 2026-05-06 12:17:42 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-05-06 12:17:42 :: PlotLatLonProfiles :: INFO     -> Description: Climatological zonal profile of total precipitation rate over Tropics for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-05-06 12:17:42 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-05-06 12:17:43 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.tropics.png
# 2026-05-06 12:17:43 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# ## Multiple plot - Seasonal mean profiles
#
# As for the annual mean plot, same logic applies also for seasonal profiles:

# %%
# Prepare model data for 4 seasons
combined_seasonal_model_data = []
combined_seasonal_ref_data = []

for i in range(4):  # DJF, MAM, JJA, SON
    combined_seasonal_model_data.append(
        [
            lonlat_dataset_1.seasonal[i],  # ICON tprate - 1990-1999 - season i
            lonlat_dataset_2.seasonal[i],  # ICON tprate - 2030-2039 - season i
            lonlat_dataset_3.seasonal[i],  # IFS-NEMO tprate - 1990-1999 - season i
            lonlat_dataset_4.seasonal[i],  # IFS-NEMO tprate - 2030-2039 - season i
        ]
    )
    combined_seasonal_ref_data.append(lonlat_obs.seasonal[i])

# Prepare std data for reference only
multi_ref_std_data = [lonlat_obs.std_seasonal[i] for i in range(4)]

# Create 4-panel seasonal plot with multiple variables
seasonal_multi_plot = PlotLatLonProfiles(
    data=combined_seasonal_model_data,
    ref_data=combined_seasonal_ref_data,
    ref_std_data=multi_ref_std_data,
    data_type="seasonal",
    loglevel="INFO",
)

# Run the seasonal plot (multi_var_labels is already defined in the previous cell)
seasonal_multi_plot.run(show=True, format="png")
# Out:
# 2026-05-06 12:17:43 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-05-06 12:17:43 :: PlotLatLonProfiles :: INFO     -> Description: Seasonal zonal profile of total precipitation rate over Tropics for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-05-06 12:17:43 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-05-06 12:17:44 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.seasonal_zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.tropics.png
# 2026-05-06 12:17:44 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully
