# %% [markdown]
# # LatLonProfiles diagnostic - Single line profiles
#
# The aim of this diagnostic is to visualise latitudinal or longitudinal profiles of a certain variable. In addition, plots are allowed to have multiple lines and/or show the seasonal and annual means of the selected variable.
#
# Specifically, in this notebook we look at the code for example plots of a single line zonal profile (along with the reference data).

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start with the import of the classes `LatLonProfiles` and `PlotLatLonProfiles`:

# %%
from aqua.diagnostics import LatLonProfiles, PlotLatLonProfiles

# %% [markdown]
# We generate a dictionary, `dataset_dict`, including the data we want to plot in this notebook.
# The plot of a reference profile to be plotted along with the input dataset is optional. If chosen, `obs_dict` is necessary.
# Lastly, `common_dict` include the common features for both datasets (input and reference).

# %%
dataset_dict = {
    "catalog": "climatedt-gen2",
    "model": "IFS-FESOM-5km",
    "exp": "baseline-hist",
    "source": "lra-r100-monthly",
    "startdate": "1995-01-01",
    "enddate": "2010-12-31",
}
obs_dict = {
    "catalog": "obs",
    "model": "ERA5",
    "exp": "era5",
    "source": "monthly",
    "startdate": "1990-01-01",
    "enddate": "2014-12-31",
    "std_startdate": "2000-01-01",
    "std_enddate": "2012-12-31",
}
common_dict = {"loglevel": "info"}

# %% [markdown]
# We hence generate an object of the `LatLonProfiles` class, and we decide to plot a zonal profile as an example. This means that the code will be performing the zonal mean, by averaging across the longitudes.
#
# The analysed variable for this notebook will be `tprate` (Total Precipitation Rate, expressed in mm/day).
#
# By default, the `mean_type` parameter in set as 'zonal' (so the profile will be zonal even without a specific `mean_type` setting), but to visualise the meridional profile, one can just set `mean_type='meridional'`. We also generate another LatLonProfiles object for the reference zonal profile.
#
# The `std=True` option computes the standard deviation and is optional. We set it as `True` for the ERA5 reference profile to enable uncertainty shading in plots. Model data can also compute std, but for plotting simplicity, only reference std shading is directly supported via `ref_std_data`.

# %%
lonlat_dataset = LatLonProfiles(**dataset_dict, **common_dict, mean_type="zonal")
lonlat_obs = LatLonProfiles(**obs_dict, **common_dict, mean_type="zonal")

run_dict = {"var": "tprate", "units": "mm/day"}

lonlat_dataset.run(**run_dict, std=True)
lonlat_obs.run(**run_dict, std=True)
# Out:
# 2026-05-06 12:10:40 :: LatLonProfiles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2026-05-06 12:10:40 :: LatLonProfiles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2026-05-06 12:10:40 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:10:40 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:10:40 :: ConfigPath :: INFO     -> IFS-FESOM-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-05-06 12:10:40 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:10:40 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-05-06 12:10:41 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-05-06 12:10:41 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-05-06 12:10:41 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-05-06 12:11:15 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:11:15 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-05-06 12:11:15 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-05-06 12:11:15 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-05-06 12:11:15 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-05-06 12:11:15 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-05-06 12:11:15 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:11:15 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:11:15 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-05-06 12:11:15 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-05-06 12:11:15 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:11:15 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:11:15 :: LatLonProfiles :: INFO     -> Start date: 1995-01-01
# 2026-05-06 12:11:15 :: LatLonProfiles :: INFO     -> End date: 2010-12-31
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:11:16 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:16 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:11:16 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:16 :: timmean_chunking :: INFO     -> 63 chunks from 1995-03-01 00:00:00 to 2010-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:11:16 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:11:16 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:16 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:11:16 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:16 :: timmean_chunking :: INFO     -> 192 chunks from 1995-01-01 00:00:00 to 2010-12-01 00:00:00 at MS frequency to be analysed
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.djf.tprate.nc
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.mam.tprate.nc
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.jja.tprate.nc
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.son.tprate.nc
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.djf.std.tprate.nc
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.mam.std.tprate.nc
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.jja.std.tprate.nc
# 2026-05-06 12:11:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.son.std.tprate.nc
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:11:17 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:11:17 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:11:17 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:11:17 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:17 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:11:18 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:18 :: timmean_chunking :: INFO     -> 192 chunks from 1995-01-01 00:00:00 to 2010-12-01 00:00:00 at MS frequency to be analysed
# 2026-05-06 12:11:18 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:11:18 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:18 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:18 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.longterm.tprate.nc
# 2026-05-06 12:11:18 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:18 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.longterm.std.tprate.nc
# 2026-05-06 12:11:18 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-05-06 12:11:18 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-05-06 12:11:18 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2026-05-06 12:11:18 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2026-05-06 12:11:19 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-05-06 12:11:19 :: FixerConfigure :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2026-05-06 12:11:19 :: FixerConfigure :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2026-05-06 12:11:19 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2026-05-06 12:11:19 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2026-05-06 12:11:19 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2026-05-06 12:11:19 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-05-06 12:11:19 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:11:19 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-05-06 12:11:21 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2026-05-06 12:11:21 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2026-05-06 12:11:21 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-05-06 12:11:21 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> End date: 2014-12-31
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:11:21 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-05-06 12:11:21 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:21 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2026-05-06 12:11:21 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:21 :: timmean_chunking :: INFO     -> 99 chunks from 1990-03-01 00:00:00 to 2014-09-01 00:00:00 at QS-DEC frequency to be analysed
# 2026-05-06 12:11:23 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:11:23 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-05-06 12:11:23 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:23 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:11:24 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:24 :: timmean_chunking :: INFO     -> 156 chunks from 2000-01-01 00:00:00 to 2012-12-01 00:00:00 at MS frequency to be analysed
# 2026-05-06 12:11:29 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-05-06 12:11:29 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.tprate.nc
# 2026-05-06 12:11:29 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.tprate.nc
# 2026-05-06 12:11:29 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.tprate.nc
# 2026-05-06 12:11:29 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.tprate.nc
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:29 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.std.tprate.nc
# 2026-05-06 12:11:29 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:30 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.std.tprate.nc
# 2026-05-06 12:11:30 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:30 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.std.tprate.nc
# 2026-05-06 12:11:30 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:30 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.std.tprate.nc
# 2026-05-06 12:11:30 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:11:30 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-05-06 12:11:30 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-05-06 12:11:30 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:39 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:11:39 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-05-06 12:11:39 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-05-06 12:11:39 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-05-06 12:11:40 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-05-06 12:11:40 :: timmean_chunking :: INFO     -> 156 chunks from 2000-01-01 00:00:00 to 2012-12-01 00:00:00 at MS frequency to be analysed
# 2026-05-06 12:11:45 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-05-06 12:11:45 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-05-06 12:11:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.tprate.nc
# 2026-05-06 12:11:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-05-06 12:11:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.std.tprate.nc
# 2026-05-06 12:11:45 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed

# %% [markdown]
# Different types of dataset can be managed and plotted via `LatLonProfiles` and `PlotLatLonProfiles`:
# - Seasonal mean, with season choice between DJF, MAM, JJA and SON
# - Annual mean
#
# ## Single plot - Seasonal means
# We can choose to select a specific season from `lonlat_dataset.seasonal` (which contains [DJF, MAM, JJA, SON]) or use the annual mean from `lonlat_dataset.annual`.
#
# Standard deviation shading is supported for reference data through the `ref_std_data` parameter. This provides uncertainty bands around the reference data to aid in model validation.
#
# The seasonal data is a list with 4 elements:
# - Index 0: DJF (December-January-February)
# - Index 1: MAM (March-April-May)
# - Index 2: JJA (June-July-August)
# - Index 3: SON (September-October-November)

# %%
# Seasonal data example:
single_season = lonlat_dataset.seasonal[0]  # DJF (winter)
single_season_obs = lonlat_obs.seasonal[0]  # DJF (winter) for reference

# Annual data example:
# single_annual = lonlat_dataset.annual
# single_annual_obs = lonlat_obs.annual

data_to_use = single_season
ref_data_to_use = single_season_obs

plot_dict = {
    "data": [data_to_use],  # Note: needs to be a list
    "ref_data": ref_data_to_use,  # Reference data
    "data_type": "longterm",
    "ref_std_data": lonlat_obs.std_seasonal[0],  # DJF std for reference data
    "loglevel": "INFO",
}

# %% [markdown]
# We here plot the single profile, retrieve the plot labels and info via the metadata. Lastly, we save the plot:

# %%
plot = PlotLatLonProfiles(**plot_dict)
plot.run(show=True, format="png")
# Out:
# 2026-05-06 12:11:46 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-05-06 12:11:46 :: PlotLatLonProfiles :: INFO     -> Description: Climatological zonal profile of total precipitation rate for IFS-FESOM-5km baseline-hist from 1995-01 to 2010-12 compared to ERA5 era5 (from 1990-01 to 2014-12) with ±2σ uncertainty bands (from 2000-01 to 2012-12).
# 2026-05-06 12:11:46 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-05-06 12:11:46 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.tprate.png
# 2026-05-06 12:11:46 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# ## Single plot - Annual mean
#
# Lastly, with the same logic we plot the annual mean for the `lonlat_dataset` object along with the reference data:

# %%
annual_plot = PlotLatLonProfiles(
    data=[lonlat_dataset.longterm], ref_data=lonlat_obs.longterm, ref_std_data=lonlat_obs.std_annual, data_type="longterm"
)
annual_plot.run(show=True, format="png")

# %% [markdown]
# ## Multiple plot - Seasonal mean profiles
#
# Via `PlotLatLonProfiles` we can also show the 4 seasons means represented in four subplots. Standard deviation shading is available for reference data through `ref_std_data`.

# %%
combined_seasonal_model_data = []
combined_seasonal_ref_data = []

for i in range(4):  # DJF, MAM, JJA, SON
    combined_seasonal_model_data.append(lonlat_dataset.seasonal[i])  # Model data as list
    combined_seasonal_ref_data.append(lonlat_obs.seasonal[i])  # Reference data

# Prepare std data for all 4 seasons
ref_std_data = [lonlat_obs.std_seasonal[i] for i in range(4)]  # Reference std for all seasons

seasonal_plot = PlotLatLonProfiles(
    data=combined_seasonal_model_data,
    ref_data=combined_seasonal_ref_data,
    ref_std_data=ref_std_data,
    data_type="seasonal",
    loglevel="INFO",
)

seasonal_plot.run(show=True, format="png")
# Out:
# 2026-05-06 12:11:47 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-05-06 12:11:47 :: PlotLatLonProfiles :: INFO     -> Description: Seasonal zonal profile of total precipitation rate for IFS-FESOM-5km baseline-hist from 1995-01 to 2010-12 compared to ERA5 era5 (from 1990-01 to 2014-12) with ±2σ uncertainty bands (from 2000-01 to 2012-12).
# 2026-05-06 12:11:47 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-05-06 12:11:48 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.seasonal_zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.tprate.png
# 2026-05-06 12:11:48 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully
