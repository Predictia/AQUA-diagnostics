# %% [markdown]
# # LatLonProfiles diagnostic - Single line profiles
#
# The aim of this diagnostic is to visualise latitudinal or longitudinal profiles of a certain variable. In addition, plots are allowed to have multiple lines and/or show the seasonal and annual means of the selected variable.
#
# Specifically, in this notebook we look at the code for example plots of a single line zonal profile (along with the reference data).

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start with the import of the classes `LatLonProfiles` and `PlotLatLonProfiles`:

# %%
from aqua.diagnostics.lat_lon_profiles import LatLonProfiles
from aqua.diagnostics.lat_lon_profiles import PlotLatLonProfiles
# Out:
# /LUMI_TYKKY_vLfLTcc/miniforge/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# We generate a dictionary, `dataset_dict`, including the data we want to plot in this notebook.
# The plot of a reference profile to be plotted along with the input dataset is optional. If chosen, `obs_dict` is necessary.
# Lastly, `common_dict` include the common features for both datasets (input and reference).

# %%
dataset_dict = {'catalog': 'climatedt-phase1',
                'model': 'ICON',
                'exp': 'historical-1990',
                'source': 'lra-r100-monthly'}
obs_dict = {'catalog': 'obs',
            'model': 'ERA5',
            'exp': 'era5',
            'source': 'monthly',
            'std_startdate': '1990-01-01',
            'std_enddate': '1999-12-31'}
common_dict = {'startdate': '1990-01-01',
               'enddate': '1999-12-31',
               'loglevel': 'info'}

# %% [markdown]
# We hence generate an object of the `LatLonProfiles` class, and we decide to plot a zonal profile as an example. This means that the code will be performing the zonal mean, by averaging across the longitudes.
#
# The analysed variable for this notebook will be `tprate` (Total Precipitation Rate, expressed in mm/day).
#
# By default, the `mean_type` parameter in set as 'zonal' (so the profile will be zonal even without a specific `mean_type` setting), but to visualise the meridional profile, one can just set `mean_type='meridional'`. We also generate another LatLonProfiles object for the reference zonal profile.
#
# The `std=True` option computes the standard deviation and is optional. We set it as `True` for the ERA5 reference profile to enable uncertainty shading in plots. Model data can also compute std, but for plotting simplicity, only reference std shading is directly supported via `ref_std_data`.

# %%
lonlat_dataset = LatLonProfiles(**dataset_dict, **common_dict, mean_type='zonal')
lonlat_obs = LatLonProfiles(**obs_dict, **common_dict, mean_type='zonal')

run_dict = {'var': 'tprate',
            'units': 'mm/day'}

lonlat_dataset.run(**run_dict, std=True)
lonlat_obs.run(**run_dict, std=True)
# Out:
# 2025-09-15 11:49:24 :: LatLonProfiles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-09-15 11:49:24 :: LatLonProfiles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-09-15 11:49:24 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-09-15 11:49:24 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-09-15 11:49:24 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-09-15 11:49:24 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-09-15 11:49:24 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-09-15 11:49:24 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-09-15 11:49:24 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-09-15 11:49:24 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-09-15 11:49:24 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-09-15 11:49:43 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-09-15 11:49:43 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-09-15 11:49:43 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-09-15 11:49:44 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-09-15 11:49:44 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-09-15 11:49:44 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-09-15 11:49:44 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-09-15 11:49:44 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2025-09-15 11:49:44 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-15 11:49:44 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-09-15 11:49:44 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-09-15 11:49:44 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-09-15 11:49:44 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-09-15 11:49:44 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-09-15 11:49:44 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:44 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-09-15 11:49:45 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-09-15 11:49:45 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:45 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-09-15 11:49:45 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-09-15 11:49:45 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Saving DJF data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.DJF.tprate.nc
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Saving MAM data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.MAM.tprate.nc
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Saving JJA data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.JJA.tprate.nc
# 2025-09-15 11:49:45 :: LatLonProfiles :: INFO     -> Saving SON data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:45 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.SON.tprate.nc
# 2025-09-15 11:49:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.DJF.std.tprate.nc
# 2025-09-15 11:49:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.MAM.std.tprate.nc
# 2025-09-15 11:49:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.JJA.std.tprate.nc
# 2025-09-15 11:49:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:47 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.seasonal.SON.std.tprate.nc
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-09-15 11:49:47 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-09-15 11:49:47 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-09-15 11:49:47 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:47 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-09-15 11:49:47 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-09-15 11:49:47 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-09-15 11:49:47 :: LatLonProfiles :: INFO     -> Saving longterm data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:47 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:47 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.longterm.tprate.nc
# 2025-09-15 11:49:47 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:48 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.climatedt-phase1.ICON.historical-1990.r1.annual.std.tprate.nc
# 2025-09-15 11:49:48 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2025-09-15 11:49:48 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2025-09-15 11:49:48 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# 2025-09-15 11:49:48 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-09-15 11:49:48 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-09-15 11:49:48 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-09-15 11:49:48 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-09-15 11:49:48 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-09-15 11:49:48 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-09-15 11:49:48 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_era5-r025s.nc.
# 2025-09-15 11:49:48 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-09-15 11:49:48 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-15 11:49:49 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2025-09-15 11:49:49 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2025-09-15 11:49:49 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2025-09-15 11:49:49 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Loading data model from /users/cadaumar/.aqua/data_model/aqua.yaml
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-09-15 11:49:50 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2025-09-15 11:49:50 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:50 :: TimStat :: INFO     -> Resampling to QS-DEC frequency and computing mean...
# 2025-09-15 11:49:50 :: TimStat :: WARNING  -> Excluding incomplete chunks is not supported for seasonal averaging, skipping this option...
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-09-15 11:49:50 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2025-09-15 11:49:50 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:49:50 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-09-15 11:49:50 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-09-15 11:49:50 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-09-15 11:49:51 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2025-09-15 11:49:51 :: LatLonProfiles :: INFO     -> Saving DJF data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:51 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:51 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.DJF.tprate.nc
# 2025-09-15 11:49:51 :: LatLonProfiles :: INFO     -> Saving MAM data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:51 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:52 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.MAM.tprate.nc
# 2025-09-15 11:49:52 :: LatLonProfiles :: INFO     -> Saving JJA data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:52 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:53 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.JJA.tprate.nc
# 2025-09-15 11:49:53 :: LatLonProfiles :: INFO     -> Saving SON data for zonalprofile to netcdf in ./
# 2025-09-15 11:49:53 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:53 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.SON.tprate.nc
# 2025-09-15 11:49:53 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:49:57 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.DJF.std.tprate.nc
# 2025-09-15 11:49:57 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:50:01 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.MAM.std.tprate.nc
# 2025-09-15 11:50:01 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:50:04 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.JJA.std.tprate.nc
# 2025-09-15 11:50:04 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:50:08 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.seasonal.SON.std.tprate.nc
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2025-09-15 11:50:08 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2025-09-15 11:50:08 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2025-09-15 11:50:08 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2025-09-15 11:50:08 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-09-15 11:50:08 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-09-15 11:50:08 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2025-09-15 11:50:08 :: LatLonProfiles :: INFO     -> Saving longterm data for zonalprofile to netcdf in ./
# 2025-09-15 11:50:08 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:50:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.longterm.tprate.nc
# 2025-09-15 11:50:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-09-15 11:50:15 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonalprofile.obs.ERA5.era5.r1.annual.std.tprate.nc
# 2025-09-15 11:50:15 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed

# %% [markdown]
# Different types of dataset can be managed and plotted via `LatLonProfiles` and `PlotLatLonProfiles`:
# - Seasonal mean, with season choice between DJF, MAM, JJA and SON
# - Annual mean
#
# ## Single plot - Seasonal means
# We can choose to select a specific season from `lonlat_dataset.seasonal` (which contains [DJF, MAM, JJA, SON]) or use the annual mean from `lonlat_dataset.annual`.
#
# Standard deviation shading is supported for reference data through the `ref_std_data` parameter. This provides uncertainty bands around the reference data to aid in model validation.
#
# The seasonal data is a list with 4 elements:
# - Index 0: DJF (December-January-February)
# - Index 1: MAM (March-April-May)
# - Index 2: JJA (June-July-August)
# - Index 3: SON (September-October-November)

# %%
# Seasonal data example:
single_season = lonlat_dataset.seasonal[0]  # DJF (winter)
single_season_obs = lonlat_obs.seasonal[0]  # DJF (winter) for reference

# Annual data example:
# single_annual = lonlat_dataset.annual
# single_annual_obs = lonlat_obs.annual

data_to_use = single_season
ref_data_to_use = single_season_obs

plot_dict = {'data': [data_to_use],  # Note: needs to be a list
             'ref_data': ref_data_to_use,  # Reference data
             'data_type': 'longterm',
             'ref_std_data': lonlat_obs.std_seasonal[0],  # DJF std for reference data
             'loglevel': 'INFO'}

# %% [markdown]
# We here plot the single profile, retrieve the plot labels and info via the metadata. Lastly, we save the plot:

# %%
plot = PlotLatLonProfiles(**plot_dict)
plot.run()
# Out:
# 2025-09-15 11:50:15 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2025-09-15 11:50:19 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-09-15 11:50:20 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/lat_lon_profiles.lat_lon_profiles_zonal.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-09-15 11:50:20 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.lat_lon_profiles_zonal.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-09-15 11:50:20 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# ## Single plot - Annual mean
#
# Lastly, with the same logic we plot the annual mean for the `lonlat_dataset` object along with the reference data:

# %%
annual_plot = PlotLatLonProfiles(
    data=[lonlat_dataset.longterm],
    ref_data=lonlat_obs.longterm,
    ref_std_data=lonlat_obs.std_annual,
    data_type='longterm'
)
annual_plot.run()

# %% [markdown]
# ## Multiple plot - Seasonal mean profiles
#
# Via `PlotLatLonProfiles` we can also show the 4 seasons means represented in four subplots. Standard deviation shading is available for reference data through `ref_std_data`.

# %%
combined_seasonal_model_data = []
combined_seasonal_ref_data = []

for i in range(4):  # DJF, MAM, JJA, SON
    combined_seasonal_model_data.append(lonlat_dataset.seasonal[i])    # Model data as list
    combined_seasonal_ref_data.append(lonlat_obs.seasonal[i])          # Reference data

# Prepare std data for all 4 seasons
ref_std_data = [lonlat_obs.std_seasonal[i] for i in range(4)]  # Reference std for all seasons

seasonal_plot = PlotLatLonProfiles(
    data=combined_seasonal_model_data,  
    ref_data=combined_seasonal_ref_data,
    ref_std_data=ref_std_data,
    data_type='seasonal', 
    loglevel='INFO'
)

seasonal_plot.run(
)
# Out:
# 2025-09-15 11:50:34 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# /pfs/lustrep3/users/cadaumar/AQUA/src/aqua/graphics/seasonal_means.py:111: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# 2025-09-15 11:50:56 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-09-15 11:50:57 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/lat_lon_profiles.lat_lon_profiles_seasonal_zonal_zonal.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-09-15 11:50:57 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.lat_lon_profiles_seasonal_zonal_zonal.climatedt-phase1.ICON.historical-1990.r1.tprate.png
# 2025-09-15 11:50:57 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully
