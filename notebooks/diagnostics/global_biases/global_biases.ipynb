# %% [markdown]
# This notebook shows how to use the global_biases diagnostic.
#
# The `GlobalBiases` class provides an easy interface to plot 2D biases maps for a given experiment and a variables with respect to some observational data.
#
# Let's plot the global mean temperature for the historical experiment, with a comparison done with the same ERA5 time span and 1990-1999 climatology.

# %%
from aqua.diagnostics import GlobalBiases, PlotGlobalBiases
# Out:
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# As a first step, we initialize the GlobalBias class for both the dataset and the reference data.

# %%
biases_ifs_nemo = GlobalBiases(model='IFS-NEMO', exp='historical-1990', source='lra-r100-monthly', startdate="1990-01-01", enddate="1999-12-31", loglevel="DEBUG")

biases_era5 = GlobalBiases(model='ERA5', exp='era5', source='monthly', startdate="1990-01-01", enddate="1999-12-31", loglevel="DEBUG")

# %% [markdown]
# Now we retrieve the data for the target variable (e.g., 'q') and compute its climatology.
# The climatology will be stored as a class attribute and can optionally be saved as a NetCDF file.

# %%
var = 'q'

biases_ifs_nemo.retrieve(var=var)
biases_ifs_nemo.compute_climatology(seasonal=True, save_netcdf=False)

biases_era5.retrieve(var=var)
biases_era5.compute_climatology(seasonal=True, save_netcdf=False)
# Out:
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Browsing catalog ci ...
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Browsing catalog climatedt-phase1 ...
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: INFO     -> IFS-NEMO_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Browsing catalog climatedt-o25.1 ...
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-o25.1/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-o25.1/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Browsing catalog obs ...
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/obs/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/obs/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Final catalog to be used is climatedt-phase1
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:06:09 :: ConfigPath :: DEBUG    -> No paths found in the main configuration file {'ci': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/ci/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/ci/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'climatedt-phase1': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'climatedt-o25.1': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/climatedt-o25.1/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/climatedt-o25.1/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'obs': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/obs/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/obs/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}}
# 2025-07-21 15:06:09 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:06:09 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/fixes
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Keys: dict_keys(['fixer_name', 'convention_name', 'defaults'])
# 2025-07-21 15:06:10 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-07-21 15:06:10 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-07-21 15:06:10 :: Fixer :: DEBUG    -> deltat = 1 defined as Fixer() default
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/grids
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:06:10 :: yaml :: DEBUG    -> Keys: dict_keys(['grids', 'weights', 'areas', 'cdo-paths'])
# 2025-07-21 15:06:10 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-07-21 15:06:10 :: Regridder :: DEBUG    -> Normalized grid dictionary: {'vert_coord': ['2d'], 'space_coord': ['lon', 'lat'], 'path': {}}
# 2025-07-21 15:06:10 :: Regridder :: DEBUG    -> Normalized grid path: {}
# 2025-07-21 15:06:10 :: Regridder :: DEBUG    -> Horizontal dimensions: ['lon', 'lat']
# 2025-07-21 15:06:10 :: Regridder :: DEBUG    -> Vertical dimensions: []
# 2025-07-21 15:06:10 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-07-21 15:06:10 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-07-21 15:06:10 :: Reader :: DEBUG    -> Getting sample data through _retrieve_plain()...
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Extra_dims are None
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Clean flag is True and cdo_weights init is False
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Grid details: ['lat', 'lon']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Horizontal dims: ['lat', 'lon']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Variables: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Bounds: []
# 2025-07-21 15:06:19 :: Reader :: DEBUG    -> Variables found: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:06:19 :: Reader :: DEBUG    -> Time dimensions found: ['time']
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Grid path {} is a valid dictionary of file paths.
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Normalized grid dictionary: {'vert_coord': ['2d'], 'space_coord': ['lon', 'lat'], 'path': {}}
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Normalized grid path: {}
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Horizontal dimensions: ['lon', 'lat']
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Vertical dimensions: []
# 2025-07-21 15:06:19 | smmregrid.GridInspect |     INFO -> Updating the log_level to DEBUG
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Extra_dims are {'vertical': [], 'horizontal': ['lon', 'lat']}
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Clean flag is True and cdo_weights init is False
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/smmregrid/gridinspector.py:83: DeprecationWarning: get_grid_info() is deprecated and will be removed in future versions. Please use get_gridtype() instead.
#   warnings.warn(
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG -> Grid details: ['lat', 'lon']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Horizontal dims: ['lat', 'lon']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Variables: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:06:19 | smmregrid.GridInspect |    DEBUG ->   Bounds: []
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Horizontal dimensions guessed from data: ['lon', 'lat']
# 2025-07-21 15:06:19 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Found CDO path: /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/bin/cdo
# 2025-07-21 15:06:19 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Grid dictionary: {'path': {'2d': <xarray.Dataset> Size: 133MB
# Dimensions:      (lat: 180, lon: 360, level: 75, plev: 19)
# Coordinates:
#     time         datetime64[ns] 8B 1990-01-01
#   * lat          (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lon          (lon) float64 3kB 0.0 1.0 2.0 3.0 ... 356.0 357.0 358.0 359.0
#   * level        (level) float64 600B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#     idx_level    (level) int64 600B dask.array<chunksize=(75,), meta=np.ndarray>
#   * plev         (plev) float64 152B 1e+05 9.25e+04 8.5e+04 ... 500.0 100.0
# Data variables: (12/36)
#     2t           (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_hc700m   (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_siconc   (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_sithick  (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_so       (level, lat, lon) float64 39MB dask.array<chunksize=(75, 180, 360), meta=np.ndarray>
#     avg_sos      (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     ...           ...
#     t            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>
#     tcc          (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     tciw         (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     tclw         (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     u            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>
#     v            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>}}
# 2025-07-21 15:06:19 :: Regridder :: DEBUG    -> Using source-based template for source grid. Filename: cell_area_IFS-NEMO_historical-1990_lra-r100-monthly.nc
# 2025-07-21 15:06:19 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_IFS-NEMO_historical-1990_lra-r100-monthly.nc.
# 2025-07-21 15:06:19 :: FixerDataModel :: DEBUG    -> Applying fixes to area file
# 2025-07-21 15:06:19 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:06:19 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:06:19 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:06:19 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:06:19 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-07-21 15:06:19 :: Reader :: INFO     -> Retrieving variables: ['q']
# 2025-07-21 15:06:19 :: Fixer :: DEBUG    -> Variables in the fixes: {'2d': {'source': [168, 235168, '2d', 'avg_2d', 'D2M', 'tdps'], 'grib': 168}, '2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}, '10u': {'source': [165, 235165, '10u', 'm10u', 'avg_10u', 'U10M', 'u10', 'uas'], 'grib': 165}, '10v': {'source': [166, 235166, '10v', 'm10v', 'avg_10v', 'V10M', 'v10', 'vas'], 'grib': 166}, 'clwc': {'source': [246, 235246, 'clwc', 'avg_clwc', 'lwp'], 'grib': 246}, 'hcc': {'source': [3075, 188, 235110, 235188, 'hcc', 'avg_hcc', 'avg_hcc_frac', 'HCC'], 'grib': 3075}, 'lcc': {'source': [3073, 186, 235108, 235186, 'lcc', 'avg_lcc', 'avg_lcc_frac', 'LCC'], 'grib': 3073}, 'mcc': {'source': [3074, 187, 235109, 235187, 'mcc', 'avg_mcc', 'avg_mcc_frac', 'MCC'], 'grib': 3074}, 'msl': {'source': [151, 235151, 'msl', 'avg_msl', 'mmsl', 'sea_level_pressure', 'MSL', 'psl'], 'grib': 151}, 'pv': {'source': [60, 235100, 'pv', 'avg_pv'], 'grib': 60}, 'q': {'source': [133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus'], 'grib': 133}, 'r': {'source': [157, 235157, 'r', 'avg_r', 'hur'], 'grib': 157}, 'sd': {'source': [141, 228141, 235141, 235078, 'sd', 'avg_sd', 'msd', 'avg_sd_m', 'snw'], 'grib': 228141}, 'skt': {'source': [235, 235079, 'skt', 'avg_skt', 'mskt', 'ts'], 'grib': 235}, 'sp': {'source': [134, 235134, 'sp', 'avg_sp', 'ps'], 'grib': 134}, 'ssurfror': {'source': [9, 235021, 231011, 172009, 'ssro', 'ssurfror', 'mssror', 'avg_ssurfror', 'mrrob'], 'grib': 231011}, 'surfror': {'source': [8, 235020, 231009, 172008, 'sro', 'avg_surfror', 'msror', 'surfror', 'mrros'], 'grib': 231009}, 't': {'source': [130, 235130, 't', 'avg_t', 'mt', 'T', 'ta'], 'grib': 130}, 'tcc': {'source': [164, 228006, 228164, 131164, 'tcc', 'meantcc', 'avg_tcc', 'TCC', 'clt'], 'grib': 228164}, 'tciw': {'source': [79, 235088, 'tciw', 'avg_tciw', 'clivi'], 'grib': 79}, 'tclw': {'source': [78, 235087, 'tclw', 'avg_tclw', 'cllvi', 'lwp'], 'grib': 78}, 'tcwv': {'source': [137, 235137, 'tcwv', 'avg_tcwv', 'prw'], 'grib': 137}, 'u': {'source': [131, 235131, 'u', 'avg_u', 'U', 'ua'], 'grib': 131}, 'v': {'source': [132, 235132, 'v', 'avg_v', 'V', 'va'], 'grib': 132}, 'w': {'source': [135, 235135, 'w', 'avg_w', 'wa'], 'grib': 135}, 'z': {'source': [129, 235129, 'z', 'avg_z'], 'grib': 129}, 'cprea': {'source': [143, 160143, 'cp', 'prc'], 'grib': 160143}, 'ie': {'source': [232, 235043, 182, 'e', 'ie', 'avg_ie', 'mer', 'E', 'evspsbl'], 'grib': 232}, 'iews': {'source': [235041, 229, 'ews', 'iews', 'avg_iews', 'metss', 'ewss', 'tauu'], 'grib': 229}, 'inss': {'source': [235042, 230, 'nss', 'inss', 'avg_inss', 'mntss', 'nsss', 'tauv'], 'grib': 230}, 'ishf': {'source': [231, 146, 235033, 'ishf', 'avg_ishf', 'SSHF', 'sshf', 'msshf', 'hfss'], 'grib': 231}, 'lsprate': {'source': [142, 260050, 'lsp', 'prlr'], 'grib': 260050}, 'sdlwrf': {'source': [260097, 175, 235036, 'sdlwrf', 'avg_sdlwrf', 'msdwlwrf', 'strd', 'STRD', 'rlds'], 'grib': 260097}, 'sdswrf': {'source': [169, 260087, 235035, 'sdswrf', 'avg_sdswrf', 'msdwswrf', 'ssrd', 'msdsrf', 'SSRD', 'rsds'], 'grib': 260087}, 'slhtf': {'source': [147, 260002, 235034, 'slhtf', 'avg_slhtf', 'mslhf', 'slhf', 'SLHF'], 'grib': 260002}, 'snlwrf': {'source': [177, 260099, 235038, 'snlwrf', 'avg_snlwrf', 'msnlwrf', 'str', 'STR'], 'grib': 260099}, 'snlwrfcs': {'source': [211, 260100, 235052, 'snlwrcs', 'snlwrfcs', 'avg_snlwrfcs', 'msnlwrfcs', 'strc', 'STRC'], 'grib': 260100}, 'snswrf': {'source': [176, 260089, 235037, 'snswrf', 'avg_snswrf', 'msnswrf', 'ssr', 'SSR'], 'grib': 260089}, 'snswrfcs': {'source': [210, 260091, 235051, 'snswrfcs', 'avg_snswrfcs', 'msnswrfcs', 'ssrc', 'SSRC'], 'grib': 260091}, 'tdswrf': {'source': [212, 260676, 235053, 'tdswrf', 'avg_tdswrf', 'mtdwswrf', 'tisr', 'TISR', 'rsdt'], 'grib': 260676}, 'tnlwrf': {'source': [179, 260672, 235040, 'tnlwrf', 'avg_tnlwrf', 'mtnlwrf', 'ttr', 'TTR'], 'grib': 260672}, 'tnlwrfcs': {'source': [209, 260675, 235050, 'tnlwrfcs', 'avg_tnlwrfcs', 'mtnlwrfcs', 'ttrc', 'TTRC'], 'grib ...
# 2025-07-21 15:06:19 :: Fixer :: DEBUG    -> Variables to be loaded: [[133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus']]
# 2025-07-21 15:06:19 :: Fixer :: INFO     -> Variables to be fixed: {'q': {'source': [133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus'], 'grib': 133}}
# 2025-07-21 15:06:19 :: Fixer :: DEBUG    -> Grib variable var133, looking for attributes
# 2025-07-21 15:06:19 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var133
# 2025-07-21 15:06:20 :: eccodes :: DEBUG    -> Trying short name q with GRIB version GRIB2 and table 0
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> Grib variable var133, shortname is q
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> For grib variable var133 find eccodes shortname q, replacing it
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> Grib attributes for q: {'paramId': '133', 'long_name': 'Specific humidity', 'units': 'kg kg**-1', 'shortName': 'q', 'cfVarName': 'q'}
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> Name of fixer var: q
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> Name of data source var: q
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> Name of target var: q
# 2025-07-21 15:06:20 :: Fixer :: INFO     -> q: converting units kg kg**-1 --> kg kg**-1
# 2025-07-21 15:06:20 :: FixerOperator :: DEBUG    -> q: org_units is kg kg**-1, tgt_units is None
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: time
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> time
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: plev
# 2025-07-21 15:06:20 :: CoordIdentifier :: DEBUG    -> isobaric
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate lat
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate lon
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Analysing coordinate: isobaric
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate plev
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute axis to coordinate plev
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:06:20 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> time unit not found in target data model. Disabling unit conversion.
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute standard_name to coordinate time
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate time
# 2025-07-21 15:06:20 :: CoordTransator :: DEBUG    -> Adding attribute axis to coordinate time
# 2025-07-21 15:06:20 :: Global Biases :: WARNING  -> Variable 'q' has multiple pressure levels, but none was specified.
# 2025-07-21 15:06:20 :: Global Biases :: INFO     -> Computing climatology for variable q.
# 2025-07-21 15:06:20 :: Global Biases :: INFO     -> Computing seasonal climatology for variable q.
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Updating the log_level to DEBUG
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Browsing catalog ci ...
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Browsing catalog climatedt-phase1 ...
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Browsing catalog climatedt-o25.1 ...
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-o25.1/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-o25.1/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Browsing catalog obs ...
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/obs/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/obs/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Final catalog to be used is obs
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/obs/catalog.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/obs/machine.yaml
# 2025-07-21 15:06:20 :: ConfigPath :: DEBUG    -> No paths found in the main configuration file {'ci': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/ci/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/ci/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'climatedt-phase1': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'climatedt-o25.1': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/climatedt-o25.1/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/climatedt-o25.1/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}, 'obs': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/obs/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/obs/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}}
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/fixes
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Keys: dict_keys(['fixer_name', 'convention_name', 'defaults'])
# 2025-07-21 15:06:20 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-07-21 15:06:20 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-07-21 15:06:20 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-07-21 15:06:20 :: Fixer :: DEBUG    -> deltat = 1 defined as Fixer() default
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:06:20 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/grids
# 2025-07-21 15:06:21 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:06:21 :: yaml :: DEBUG    -> Keys: dict_keys(['grids', 'weights', 'areas', 'cdo-paths'])
# 2025-07-21 15:06:21 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Grid path {'2d': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid.nc', '2dm': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid_masked.nc'} is a valid dictionary of file paths.
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Normalized grid dictionary: {'path': {'2d': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid.nc', '2dm': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid_masked.nc'}, 'masked': {'vars': ['SSTK', 'sst', 'tos']}, 'space_coord': ['lon', 'lat'], 'vert_coord': ['2d', '2dm']}
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Normalized grid path: {'2d': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid.nc', '2dm': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid_masked.nc'}
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Horizontal dimensions: ['lon', 'lat']
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Vertical dimensions: ['2d', '2dm']
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Found CDO path: /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/bin/cdo
# 2025-07-21 15:06:21 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Grid dictionary: {'path': {'2d': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid.nc', '2dm': '/pfs/lustrep3/appl/local/climatedt/data/AQUA/grids/ERA5/r025_grid_masked.nc'}, 'masked': {'vars': ['SSTK', 'sst', 'tos']}, 'space_coord': ['lon', 'lat'], 'vert_coord': ['2d', '2dm']}
# 2025-07-21 15:06:21 :: Regridder :: DEBUG    -> Using grid-based template for source grid. Filename: cell_area_era5-r025s.nc
# 2025-07-21 15:06:21 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_era5-r025s.nc.
# 2025-07-21 15:06:21 :: FixerDataModel :: DEBUG    -> Applying fixes to area file
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-07-21 15:06:21 :: Reader :: INFO     -> Retrieving variables: ['q']
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Variables in the fixes: {'ie': {'source': 'E', 'grib': 232, 'src_units': 'm/day'}, 'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}, 'slhtf': {'source': 'SLHF', 'grib': 260002, 'src_units': 'J m**-2 day**-1'}, 'ishf': {'source': 'SSHF', 'grib': 231, 'src_units': 'J m**-2 day**-1'}, 'snswrf': {'source': 'SSR', 'grib': 260089, 'src_units': 'J m**-2 day**-1'}, 'sdswrf': {'source': 'SSRD', 'grib': 260087, 'src_units': 'J m**-2 day**-1'}, 'snlwrf': {'source': 'STR', 'grib': 260099, 'src_units': 'J m**-2 day**-1'}, 'sdlwrf': {'source': 'STRD', 'grib': 260097, 'src_units': 'J m**-2 day**-1'}, 'tnswrf': {'source': 'TSR', 'grib': 260671, 'src_units': 'J m**-2 day**-1'}, 'tnlwrf': {'source': 'TTR', 'grib': 260672, 'src_units': 'J m**-2 day**-1'}, '2d': {'source': [168, 235168, '2d', 'avg_2d', 'D2M', 'tdps'], 'grib': 168}, '2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}, '10u': {'source': [165, 235165, '10u', 'm10u', 'avg_10u', 'U10M', 'u10', 'uas'], 'grib': 165}, '10v': {'source': [166, 235166, '10v', 'm10v', 'avg_10v', 'V10M', 'v10', 'vas'], 'grib': 166}, 'clwc': {'source': [246, 235246, 'clwc', 'avg_clwc', 'lwp'], 'grib': 246}, 'hcc': {'source': [3075, 188, 235110, 235188, 'hcc', 'avg_hcc', 'avg_hcc_frac', 'HCC'], 'grib': 3075}, 'lcc': {'source': [3073, 186, 235108, 235186, 'lcc', 'avg_lcc', 'avg_lcc_frac', 'LCC'], 'grib': 3073}, 'mcc': {'source': [3074, 187, 235109, 235187, 'mcc', 'avg_mcc', 'avg_mcc_frac', 'MCC'], 'grib': 3074}, 'msl': {'source': [151, 235151, 'msl', 'avg_msl', 'mmsl', 'sea_level_pressure', 'MSL', 'psl'], 'grib': 151}, 'pv': {'source': [60, 235100, 'pv', 'avg_pv'], 'grib': 60}, 'q': {'source': [133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus'], 'grib': 133}, 'r': {'source': [157, 235157, 'r', 'avg_r', 'hur'], 'grib': 157}, 'sd': {'source': [141, 228141, 235141, 235078, 'sd', 'avg_sd', 'msd', 'avg_sd_m', 'snw'], 'grib': 228141}, 'skt': {'source': [235, 235079, 'skt', 'avg_skt', 'mskt', 'ts'], 'grib': 235}, 'sp': {'source': [134, 235134, 'sp', 'avg_sp', 'ps'], 'grib': 134}, 'ssurfror': {'source': [9, 235021, 231011, 172009, 'ssro', 'ssurfror', 'mssror', 'avg_ssurfror', 'mrrob'], 'grib': 231011}, 'surfror': {'source': [8, 235020, 231009, 172008, 'sro', 'avg_surfror', 'msror', 'surfror', 'mrros'], 'grib': 231009}, 't': {'source': [130, 235130, 't', 'avg_t', 'mt', 'T', 'ta'], 'grib': 130}, 'tcc': {'source': [164, 228006, 228164, 131164, 'tcc', 'meantcc', 'avg_tcc', 'TCC', 'clt'], 'grib': 228164}, 'tciw': {'source': [79, 235088, 'tciw', 'avg_tciw', 'clivi'], 'grib': 79}, 'tclw': {'source': [78, 235087, 'tclw', 'avg_tclw', 'cllvi', 'lwp'], 'grib': 78}, 'tcwv': {'source': [137, 235137, 'tcwv', 'avg_tcwv', 'prw'], 'grib': 137}, 'u': {'source': [131, 235131, 'u', 'avg_u', 'U', 'ua'], 'grib': 131}, 'v': {'source': [132, 235132, 'v', 'avg_v', 'V', 'va'], 'grib': 132}, 'w': {'source': [135, 235135, 'w', 'avg_w', 'wa'], 'grib': 135}, 'z': {'source': [129, 235129, 'z', 'avg_z'], 'grib': 129}, 'cprea': {'source': [143, 160143, 'cp', 'prc'], 'grib': 160143}, 'iews': {'source': [235041, 229, 'ews', 'iews', 'avg_iews', 'metss', 'ewss', 'tauu'], 'grib': 229}, 'inss': {'source': [235042, 230, 'nss', 'inss', 'avg_inss', 'mntss', 'nsss', 'tauv'], 'grib': 230}, 'lsprate': {'source': [142, 260050, 'lsp', 'prlr'], 'grib': 260050}, 'snlwrfcs': {'source': [211, 260100, 235052, 'snlwrcs', 'snlwrfcs', 'avg_snlwrfcs', 'msnlwrfcs', 'strc', 'STRC'], 'grib': 260100}, 'snswrfcs': {'source': [210, 260091, 235051, 'snswrfcs', 'avg_snswrfcs', 'msnswrfcs', 'ssrc', 'SSRC'], 'grib': 260091}, 'tdswrf': {'source': [212, 260676, 235053, 'tdswrf', 'avg_tdswrf', 'mtdwswrf', 'tisr', 'TISR', 'rsdt'], 'grib': 260676}, 'tnlwrfcs': {'source': [209, 260675, 235050, 'tnlwrfcs', 'avg_tnlwrfcs', 'mtnlwrfcs', 'ttrc', 'TTRC'], 'grib': 260675}, 'tnswrfcs': {'source': [208, 260674, 235049, 'tnswrfcs', 'avg_tnswrfcs', 'mtnswrfcs', 'tsrc', 'TSRC'], 'grib': 260674}, 'tsrwe': {'source':  ...
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Variables to be loaded: [[133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus']]
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2025-07-21 15:06:21 :: Fixer :: INFO     -> Variables to be fixed: {'q': {'source': [133, 235133, 'q', 'avg_q', 'mq', 'Q', 'hus'], 'grib': 133}}
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Grib variable var133, looking for attributes
# 2025-07-21 15:06:21 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var133
# 2025-07-21 15:06:21 :: eccodes :: DEBUG    -> Trying short name q with GRIB version GRIB2 and table 0
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Grib variable var133, shortname is q
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> For grib variable var133 find eccodes shortname q, replacing it
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Grib attributes for q: {'paramId': '133', 'long_name': 'Specific humidity', 'units': 'kg kg**-1', 'shortName': 'q', 'cfVarName': 'q'}
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Name of fixer var: q
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Name of data source var: Q
# 2025-07-21 15:06:21 :: Fixer :: DEBUG    -> Name of target var: q
# 2025-07-21 15:06:21 :: Fixer :: INFO     -> q: converting units kg kg**-1 --> kg kg**-1
# 2025-07-21 15:06:21 :: FixerOperator :: DEBUG    -> q: org_units is kg kg**-1, tgt_units is None
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: time
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> time
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: plev
# 2025-07-21 15:06:21 :: CoordIdentifier :: DEBUG    -> isobaric
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: isobaric
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:06:21 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-07-21 15:06:21 :: CoordTransator :: DEBUG    -> time unit not found in target data model. Disabling unit conversion.
# 2025-07-21 15:06:21 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate time
# 2025-07-21 15:06:21 :: Global Biases :: WARNING  -> Variable 'q' has multiple pressure levels, but none was specified.
# 2025-07-21 15:06:21 :: Global Biases :: INFO     -> Computing climatology for variable q.
# 2025-07-21 15:06:21 :: Global Biases :: INFO     -> Computing seasonal climatology for variable q.

# %% [markdown]
# Now we initialize the plotting class.
# The generated figures can optionally be saved as PNG or PDF files (enabled by default).

# %%
plot_biases = PlotGlobalBiases(save_pdf=False, save_png=False, loglevel='DEBUG')

# %% [markdown]
# Let's plot the climatology of variable 'q' at 180 hPa for the IFS-NEMO data:

# %%
plot_biases.plot_climatology(data=biases_ifs_nemo.climatology, var=var, plev=18000)
# Out:
# 2025-07-21 15:06:21 :: Global Biases :: INFO     -> Plotting climatology.
# 2025-07-21 15:06:21 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Updating the log_level to DEBUG
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:21 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:21 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:21 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:21 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:24 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:24 :: plot_single_map :: DEBUG    -> Setting vmin to 3.0073133764475453e-06, vmax to 6.025655086877107e-05
# 2025-07-21 15:06:25 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:25 :: cbar get label :: DEBUG    -> Using Specific humidity as colorbar label
# 2025-07-21 15:06:25 :: cbar get label :: DEBUG    -> Adding units to colorbar label
# 2025-07-21 15:06:25 :: plot_single_map :: DEBUG    -> Setting colorbar label to Specific humidity [kg kg**-1]
# 2025-07-21 15:06:25 :: plot_single_map :: DEBUG    -> Setting title to Climatology of Specific humidity for IFS-NEMO historical-1990 at 180 hPa
# 2025-07-21 15:06:25 :: plot_single_map :: DEBUG    -> Returning figure and axes

# %% [markdown]
# Now we plot the total bias map for variable 'q' between IFS-NEMO data and the reference dataset ERA5:

# %%
plot_biases.plot_bias(data=biases_ifs_nemo.climatology, data_ref=biases_era5.climatology, var=var, plev=18000)
# Out:
# 2025-07-21 15:06:26 :: Global Biases :: INFO     -> Plotting global biases.
# 2025-07-21 15:06:26 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:06:26 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:36 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:36 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:36 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:36 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:40 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:40 :: plot_single_map :: DEBUG    -> Setting vmin to -0.00017974055217648825, vmax to 0.00017974055217648825
# 2025-07-21 15:06:41 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:41 :: cbar get label :: DEBUG    -> Using Specific humidity as colorbar label
# 2025-07-21 15:06:41 :: cbar get label :: DEBUG    -> Adding units to colorbar label
# 2025-07-21 15:06:41 :: plot_single_map :: DEBUG    -> Setting colorbar label to Specific humidity [kg kg**-1]
# 2025-07-21 15:06:41 :: plot_single_map :: DEBUG    -> Setting colorbar ticks to be symmetrical
# 2025-07-21 15:06:41 :: set map title :: DEBUG    -> Using Specific humidity [kg kg**-1] IFS-NEMO historical-1990 as map title
# 2025-07-21 15:06:41 :: plot_single_map :: DEBUG    -> Setting title to Specific humidity [kg kg**-1] IFS-NEMO historical-1990
# 2025-07-21 15:06:41 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:06:41 :: plot_single_map_diff :: DEBUG    -> Plotting the map
# 2025-07-21 15:06:42 :: plot_single_map_diff :: DEBUG    -> Adding cyclic longitude to the difference map
# 2025-07-21 15:06:42 :: plot_single_map_diff :: DEBUG    -> Plotting the map as contour
# 2025-07-21 15:06:42 :: plot_single_map_diff :: DEBUG    -> Setting contour vmin to 3.0073133764475453e-06, vmax to 6.025655086877107e-05
# 2025-07-21 15:06:42 :: plot_single_map_diff :: DEBUG    -> Setting title to Global bias of Specific humidity for IFS-NEMO historical-1990
# relative to ERA5 climatology at 180 hPa

# %% [markdown]
# We can also do a seasonal analysis:

# %%
plot_biases.plot_seasonal_bias(data=biases_ifs_nemo.seasonal_climatology, data_ref=biases_era5.seasonal_climatology, var=var, plev=18000)
# Out:
# 2025-07-21 15:06:42 :: Global Biases :: INFO     -> Plotting seasonal biases.
# 2025-07-21 15:06:42 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:06:42 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:42 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:42 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:42 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:42 :: plot_maps :: DEBUG    -> Loading maps
# 2025-07-21 15:06:56 :: plot_maps :: DEBUG    -> Creating a 2 x 2 grid with figsize (12, 11)
# 2025-07-21 15:06:56 :: plot_maps :: DEBUG    -> Setting vmin to -0.0002833687960754378, vmax to 0.0002833687960754378
# 2025-07-21 15:06:56 :: plot_maps :: DEBUG    -> Plotting map 0
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:56 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:56 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:56 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:56 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:56 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Setting vmin to -0.0002833687960754378, vmax to 0.0002833687960754378
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Setting title to DJF
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:06:57 :: plot_maps :: DEBUG    -> Plotting map 1
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:57 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:57 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Setting vmin to -0.0002833687960754378, vmax to 0.0002833687960754378
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Setting title to MAM
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:06:57 :: plot_maps :: DEBUG    -> Plotting map 2
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:57 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:57 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:57 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:57 :: plot_single_map :: DEBUG    -> Setting vmin to -0.0002833687960754378, vmax to 0.0002833687960754378
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Setting title to JJA
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:06:58 :: plot_maps :: DEBUG    -> Plotting map 3
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:06:58 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:06:58 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:58 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Setting vmin to -0.0002833687960754378, vmax to 0.0002833687960754378
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Setting title to SON
# 2025-07-21 15:06:58 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:06:58 :: cbar get label :: DEBUG    -> Using Specific humidity as colorbar label
# 2025-07-21 15:06:58 :: cbar get label :: DEBUG    -> Adding units to colorbar label
# 2025-07-21 15:06:58 :: plot_maps :: DEBUG    -> Setting colorbar label to Specific humidity [kg kg**-1]
# 2025-07-21 15:06:58 :: plot_maps :: DEBUG    -> Setting colorbar ticks to be symmetrical

# %% [markdown]
# Finally, we can plot the vertical bias profile as a function of pressure levels:

# %%
plot_biases.plot_vertical_bias(data=biases_ifs_nemo.climatology, data_ref=biases_era5.climatology, var=var,
                                vmin= -0.002, vmax= 0.002)
# Out:
# 2025-07-21 15:06:58 :: Global Biases :: INFO     -> Plotting vertical biases for variable: q
# 2025-07-21 15:08:06 :: Global Biases :: INFO     -> Vertical bias plot completed successfully.

# %% [markdown]
# Different projections can be used to plot the bias maps. The default is `ccrs.Robinson`, but many others are available (see 'src/aqua/util/projections.py' for the full list).

# %%
projection = "nearside"
projection_params = {
    "central_longitude": -100,
    "central_latitude": 20,
    "satellite_height": 35785831
}

plot_biases.plot_bias(data=biases_ifs_nemo.climatology, data_ref=biases_era5.climatology, var=var, plev=18000, proj=projection,
                      proj_params=projection_params)
# Out:
# 2025-07-21 15:08:07 :: Global Biases :: INFO     -> Plotting global biases.
# 2025-07-21 15:08:07 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:08:07 :: Pressure levels :: INFO     -> Selecting pressure level 18000 for variable 'q'.
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:08:11 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:08:11 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:08:11 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:08:11 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Setting vmin to -0.00017974055217648825, vmax to 0.00017974055217648825
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:08:15 :: cbar get label :: DEBUG    -> Using Specific humidity as colorbar label
# 2025-07-21 15:08:15 :: cbar get label :: DEBUG    -> Adding units to colorbar label
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Setting colorbar label to Specific humidity [kg kg**-1]
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Setting colorbar ticks to be symmetrical
# 2025-07-21 15:08:15 :: set map title :: DEBUG    -> Using Specific humidity [kg kg**-1] IFS-NEMO historical-1990 as map title
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Setting title to Specific humidity [kg kg**-1] IFS-NEMO historical-1990
# 2025-07-21 15:08:15 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:08:15 :: plot_single_map_diff :: DEBUG    -> Plotting the map
# 2025-07-21 15:08:16 :: plot_single_map_diff :: DEBUG    -> Adding cyclic longitude to the difference map
# 2025-07-21 15:08:16 :: plot_single_map_diff :: DEBUG    -> Plotting the map as contour
# 2025-07-21 15:08:16 :: plot_single_map_diff :: DEBUG    -> Setting contour vmin to 3.0073133764475453e-06, vmax to 6.025655086877107e-05
# 2025-07-21 15:08:16 :: plot_single_map_diff :: DEBUG    -> Setting title to Global bias of Specific humidity for IFS-NEMO historical-1990
# relative to ERA5 climatology at 180 hPa

# %% [markdown]
# The diagnostic is also able to handle the computation of user-defined formulae:

# %%
var = 'tnlwrf+tnswrf'
long_name = 'Top net radiation'
short_name = 'tnr'

biases_ifs_nemo.retrieve(formula=True, var=var, long_name=long_name, short_name=short_name)
biases_ifs_nemo.compute_climatology(save_netcdf=False)

biases_era5.retrieve(var=var, formula=True, long_name=long_name, short_name=short_name)
biases_era5.compute_climatology(save_netcdf=False)

plot_biases = PlotGlobalBiases(save_pdf=False, save_png=False, loglevel='DEBUG')
plot_biases.plot_bias(data=biases_ifs_nemo.climatology, data_ref=biases_era5.climatology, var=short_name, plev=None)
# Out:
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Available catalogs are ['climatedt-phase1']
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Default catalog will be climatedt-phase1
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Browsing catalog climatedt-phase1 ...
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: INFO     -> IFS-NEMO_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Final catalog to be used is climatedt-phase1
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml
# 2025-07-21 15:12:28 :: ConfigPath :: DEBUG    -> No paths found in the main configuration file {'climatedt-phase1': {'catalog': ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs'], 'machine': 'lumi', 'reader': {'catalog': '/users/caprioli/.aqua/catalogs/climatedt-phase1/catalog.yaml', 'machine': '/users/caprioli/.aqua/catalogs/climatedt-phase1/machine.yaml', 'fixer': '/users/caprioli/.aqua/fixes', 'regrid': '/users/caprioli/.aqua/grids'}, 'options': {'style': 'aqua'}}}
# 2025-07-21 15:12:28 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:12:28 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/fixes
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Keys: dict_keys(['fixer_name', 'convention_name', 'defaults'])
# 2025-07-21 15:12:29 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-07-21 15:12:29 :: Fixer :: INFO     -> No fixer_name found, only convention will be applied
# 2025-07-21 15:12:29 :: Fixer :: DEBUG    -> deltat = 1 defined as Fixer() default
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Creating a new dictionary
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Folder to be merged: /users/caprioli/.aqua/grids
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Dictionary updated
# 2025-07-21 15:12:29 :: yaml :: DEBUG    -> Keys: dict_keys(['grids', 'weights', 'areas', 'cdo-paths'])
# 2025-07-21 15:12:29 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-07-21 15:12:29 :: Regridder :: DEBUG    -> Normalized grid dictionary: {'vert_coord': ['2d'], 'space_coord': ['lon', 'lat'], 'path': {}}
# 2025-07-21 15:12:29 :: Regridder :: DEBUG    -> Normalized grid path: {}
# 2025-07-21 15:12:29 :: Regridder :: DEBUG    -> Horizontal dimensions: ['lon', 'lat']
# 2025-07-21 15:12:29 :: Regridder :: DEBUG    -> Vertical dimensions: []
# 2025-07-21 15:12:29 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-07-21 15:12:29 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-07-21 15:12:29 :: Reader :: DEBUG    -> Getting sample data through _retrieve_plain()...
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),
# 2025-07-21 15:12:34 | smmregrid.GridInspect |     INFO -> Updating the log_level to DEBUG
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Extra_dims are None
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Clean flag is True and cdo_weights init is False
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Grid details: ['lat', 'lon']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Horizontal dims: ['lat', 'lon']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Variables: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Bounds: []
# 2025-07-21 15:12:34 :: Reader :: DEBUG    -> Variables found: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:12:34 :: Reader :: DEBUG    -> Time dimensions found: ['time']
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Grid path {} is a valid dictionary of file paths.
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Normalized grid dictionary: {'vert_coord': ['2d'], 'space_coord': ['lon', 'lat'], 'path': {}}
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Normalized grid path: {}
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Horizontal dimensions: ['lon', 'lat']
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Vertical dimensions: []
# 2025-07-21 15:12:34 | smmregrid.GridInspect |     INFO -> Updating the log_level to DEBUG
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Extra_dims are {'vertical': [], 'horizontal': ['lon', 'lat']}
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Clean flag is True and cdo_weights init is False
# /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/lib/python3.12/site-packages/smmregrid/gridinspector.py:83: DeprecationWarning: get_grid_info() is deprecated and will be removed in future versions. Please use get_gridtype() instead.
#   warnings.warn(
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG -> Grid details: ['lat', 'lon']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Horizontal dims: ['lat', 'lon']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Variables: ['2t', 'avg_hc700m', 'avg_siconc', 'avg_sithick', 'avg_so', 'avg_sos', 'avg_thetao', 'avg_tos', 'hcc', 'lcc', 'mcc', 'mer', 'metss', 'mntss', 'msdwlwrf', 'msdwswrf', 'msl', 'mslhf', 'msnlwrf', 'msnswrf', 'msr', 'msror', 'msshf', 'mtdwswrf', 'mtnlwrf', 'mtnswrf', 'mtpr', 'q', 'sd', 'skt', 't', 'tcc', 'tciw', 'tclw', 'u', 'v']
# 2025-07-21 15:12:34 | smmregrid.GridInspect |    DEBUG ->   Bounds: []
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Horizontal dimensions guessed from data: ['lon', 'lat']
# 2025-07-21 15:12:34 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Found CDO path: /LUMI_TYKKY_eZ1frzx/miniconda/envs/env1/bin/cdo
# 2025-07-21 15:12:34 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Grid dictionary: {'path': {'2d': <xarray.Dataset> Size: 133MB
# Dimensions:      (lat: 180, lon: 360, level: 75, plev: 19)
# Coordinates:
#     time         datetime64[ns] 8B 1990-01-01
#   * lat          (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lon          (lon) float64 3kB 0.0 1.0 2.0 3.0 ... 356.0 357.0 358.0 359.0
#   * level        (level) float64 600B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#     idx_level    (level) int64 600B dask.array<chunksize=(75,), meta=np.ndarray>
#   * plev         (plev) float64 152B 1e+05 9.25e+04 8.5e+04 ... 500.0 100.0
# Data variables: (12/36)
#     2t           (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_hc700m   (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_siconc   (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_sithick  (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     avg_so       (level, lat, lon) float64 39MB dask.array<chunksize=(75, 180, 360), meta=np.ndarray>
#     avg_sos      (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     ...           ...
#     t            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>
#     tcc          (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     tciw         (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     tclw         (lat, lon) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     u            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>
#     v            (plev, lat, lon) float64 10MB dask.array<chunksize=(19, 180, 360), meta=np.ndarray>}}
# 2025-07-21 15:12:34 :: Regridder :: DEBUG    -> Using source-based template for source grid. Filename: cell_area_IFS-NEMO_historical-1990_lra-r100-monthly.nc
# 2025-07-21 15:12:34 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_IFS-NEMO_historical-1990_lra-r100-monthly.nc.
# 2025-07-21 15:12:34 :: FixerDataModel :: DEBUG    -> Applying fixes to area file
# 2025-07-21 15:12:34 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:12:34 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:12:34 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:12:34 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:12:34 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var168, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var168
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name 2d with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var168, shortname is 2d
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var168 find eccodes shortname 2d, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for 2d: {'paramId': '168', 'long_name': '2 metre dewpoint temperature', 'units': 'K', 'shortName': '2d', 'cfVarName': 'd2m'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable 2d, no match found with sources [168, 235168, '2d', 'avg_2d', 'D2M', 'tdps']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var167, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var167
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name 2t with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var167, shortname is 2t
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var167 find eccodes shortname 2t, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for 2t: {'paramId': '167', 'long_name': '2 metre temperature', 'units': 'K', 'shortName': '2t', 'cfVarName': 't2m'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: 2t
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: 2t
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: 2t
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var165, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var165
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name 10u with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var165, shortname is 10u
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var165 find eccodes shortname 10u, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for 10u: {'paramId': '165', 'long_name': '10 metre U wind component', 'units': 'm s**-1', 'shortName': '10u', 'cfVarName': 'u10'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable 10u, no match found with sources [165, 235165, '10u', 'm10u', 'avg_10u', 'U10M', 'u10', 'uas']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var166, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var166
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name 10v with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var166, shortname is 10v
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var166 find eccodes shortname 10v, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for 10v: {'paramId': '166', 'long_name': '10 metre V wind component', 'units': 'm s**-1', 'shortName': '10v', 'cfVarName': 'v10'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable 10v, no match found with sources [166, 235166, '10v', 'm10v', 'avg_10v', 'V10M', 'v10', 'vas']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var246, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var246
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name clwc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var246, shortname is clwc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var246 find eccodes shortname clwc, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for clwc: {'paramId': '246', 'long_name': 'Specific cloud liquid water content', 'units': 'kg kg**-1', 'shortName': 'clwc', 'cfVarName': 'clwc'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable clwc, no match found with sources [246, 235246, 'clwc', 'avg_clwc', 'lwp']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3075, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var3075
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name hcc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3075, shortname is hcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var3075 find eccodes shortname hcc, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for hcc: {'paramId': '3075', 'long_name': 'High cloud cover', 'units': '%', 'shortName': 'hcc', 'cfVarName': 'hcc'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: hcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: hcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: hcc
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> hcc: converting units (0 - 1) --> %
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Fixing hcc to hcc. Unit fix: factor=100.000000
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3073, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var3073
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name lcc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3073, shortname is lcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var3073 find eccodes shortname lcc, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for lcc: {'paramId': '3073', 'long_name': 'Low cloud cover', 'units': '%', 'shortName': 'lcc', 'cfVarName': 'lcc'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: lcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: lcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: lcc
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> lcc: converting units (0 - 1) --> %
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Fixing lcc to lcc. Unit fix: factor=100.000000
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3074, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var3074
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name mcc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var3074, shortname is mcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var3074 find eccodes shortname mcc, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for mcc: {'paramId': '3074', 'long_name': 'Medium cloud cover', 'units': '%', 'shortName': 'mcc', 'cfVarName': 'mcc'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: mcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: mcc
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: mcc
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> mcc: converting units (0 - 1) --> %
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Fixing mcc to mcc. Unit fix: factor=100.000000
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var151, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var151
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name msl with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var151, shortname is msl
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var151 find eccodes shortname msl, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for msl: {'paramId': '151', 'long_name': 'Mean sea level pressure', 'units': 'Pa', 'shortName': 'msl', 'cfVarName': 'msl'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: msl
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: msl
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: msl
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> msl: converting units Pa --> Pa
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var60, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var60
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name pv with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var60, shortname is pv
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var60 find eccodes shortname pv, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for pv: {'paramId': '60', 'long_name': 'Potential vorticity', 'units': 'K m**2 kg**-1 s**-1', 'shortName': 'pv', 'cfVarName': 'pv'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable pv, no match found with sources [60, 235100, 'pv', 'avg_pv']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var133, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var133
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name q with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var133, shortname is q
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var133 find eccodes shortname q, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for q: {'paramId': '133', 'long_name': 'Specific humidity', 'units': 'kg kg**-1', 'shortName': 'q', 'cfVarName': 'q'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: q
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: q
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: q
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> q: converting units kg kg**-1 --> kg kg**-1
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var157, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var157
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name r with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var157, shortname is r
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var157 find eccodes shortname r, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for r: {'paramId': '157', 'long_name': 'Relative humidity', 'units': '%', 'shortName': 'r', 'cfVarName': 'r'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable r, no match found with sources [157, 235157, 'r', 'avg_r', 'hur']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var228141, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var228141
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name sd with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var228141, shortname is sd
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var228141 find eccodes shortname sd, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for sd: {'paramId': '228141', 'long_name': 'Snow depth water equivalent', 'units': 'kg m**-2', 'shortName': 'sd', 'cfVarName': 'sd'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: sd
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: sd
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: sd
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> sd: converting units m of water equivalent --> kg m**-2
# 2025-07-21 15:12:34 :: convert_units :: DEBUG    -> sd: corrected multiplying by density of water 1000 kg m-3
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Fixing sd to sd. Unit fix: factor=1000.000000
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var235, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var235
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name skt with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var235, shortname is skt
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var235 find eccodes shortname skt, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for skt: {'paramId': '235', 'long_name': 'Skin temperature', 'units': 'K', 'shortName': 'skt', 'cfVarName': 'skt'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: skt
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: skt
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: skt
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> skt: converting units K --> K
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var134, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var134
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name sp with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var134, shortname is sp
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var134 find eccodes shortname sp, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for sp: {'paramId': '134', 'long_name': 'Surface pressure', 'units': 'Pa', 'shortName': 'sp', 'cfVarName': 'sp'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable sp, no match found with sources [134, 235134, 'sp', 'avg_sp', 'ps']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var231011, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var231011
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name ssurfror with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var231011, shortname is ssurfror
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var231011 find eccodes shortname ssurfror, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for ssurfror: {'paramId': '231011', 'long_name': 'Sub-surface runoff rate', 'units': 'kg m**-2 s**-1', 'shortName': 'ssurfror', 'cfVarName': 'ssurfror'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> While fixing variable ssurfror, no match found with sources [9, 235021, 231011, 172009, 'ssro', 'ssurfror', 'mssror', 'avg_ssurfror', 'mrrob']
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var231009, looking for attributes
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var231009
# 2025-07-21 15:12:34 :: eccodes :: DEBUG    -> Trying short name surfror with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib variable var231009, shortname is surfror
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> For grib variable var231009 find eccodes shortname surfror, replacing it
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Grib attributes for surfror: {'paramId': '231009', 'long_name': 'Surface runoff rate', 'units': 'kg m**-2 s**-1', 'shortName': 'surfror', 'cfVarName': 'surfror'}
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of fixer var: surfror
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of data source var: msror
# 2025-07-21 15:12:34 :: Fixer :: DEBUG    -> Name of target var: surfror
# 2025-07-21 15:12:34 :: Fixer :: INFO     -> surfror: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var130, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var130
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name t with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var130, shortname is t
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var130 find eccodes shortname t, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for t: {'paramId': '130', 'long_name': 'Temperature', 'units': 'K', 'shortName': 't', 'cfVarName': 't'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: t
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: t
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: t
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> t: converting units K --> K
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var228164, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var228164
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name tcc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var228164, shortname is tcc
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var228164 find eccodes shortname tcc, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for tcc: {'paramId': '228164', 'long_name': 'Total Cloud Cover', 'units': '%', 'shortName': 'tcc', 'cfVarName': 'tcc'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: tcc
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: tcc
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: tcc
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> tcc: converting units (0 - 1) --> %
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Fixing tcc to tcc. Unit fix: factor=100.000000
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var79, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var79
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name tciw with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var79, shortname is tciw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var79 find eccodes shortname tciw, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for tciw: {'paramId': '79', 'long_name': 'Total column cloud ice water', 'units': 'kg m**-2', 'shortName': 'tciw', 'cfVarName': 'tciw'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: tciw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: tciw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: tciw
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> tciw: converting units kg m**-2 --> kg m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var78, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var78
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name tclw with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var78, shortname is tclw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var78 find eccodes shortname tclw, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for tclw: {'paramId': '78', 'long_name': 'Total column cloud liquid water', 'units': 'kg m**-2', 'shortName': 'tclw', 'cfVarName': 'tclw'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: tclw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: tclw
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: tclw
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> tclw: converting units kg m**-2 --> kg m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var137, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var137
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name tcwv with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var137, shortname is tcwv
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var137 find eccodes shortname tcwv, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for tcwv: {'paramId': '137', 'long_name': 'Total column vertically-integrated water vapour', 'units': 'kg m**-2', 'shortName': 'tcwv', 'cfVarName': 'tcwv'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> While fixing variable tcwv, no match found with sources [137, 235137, 'tcwv', 'avg_tcwv', 'prw']
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var131, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var131
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name u with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var131, shortname is u
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var131 find eccodes shortname u, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for u: {'paramId': '131', 'long_name': 'U component of wind', 'units': 'm s**-1', 'shortName': 'u', 'cfVarName': 'u'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: u
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: u
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: u
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> u: converting units m s**-1 --> m s**-1
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var132, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var132
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name v with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var132, shortname is v
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var132 find eccodes shortname v, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for v: {'paramId': '132', 'long_name': 'V component of wind', 'units': 'm s**-1', 'shortName': 'v', 'cfVarName': 'v'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: v
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: v
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: v
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> v: converting units m s**-1 --> m s**-1
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var135, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var135
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name w with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var135, shortname is w
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var135 find eccodes shortname w, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for w: {'paramId': '135', 'long_name': 'Vertical velocity', 'units': 'Pa s**-1', 'shortName': 'w', 'cfVarName': 'w'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> While fixing variable w, no match found with sources [135, 235135, 'w', 'avg_w', 'wa']
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var129, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var129
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name z with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var129, shortname is z
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var129 find eccodes shortname z, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for z: {'paramId': '129', 'long_name': 'Geopotential', 'units': 'm**2 s**-2', 'shortName': 'z', 'cfVarName': 'z'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> While fixing variable z, no match found with sources [129, 235129, 'z', 'avg_z']
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var160143, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var160143
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name cprea with GRIB version GRIB2 and table 0
# ECCODES ERROR   :  concept: no match for shortName=cprea
# ECCODES ERROR   :  concept: input handle edition=2, centre=0
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Failed guessing for shortName GRIB2, grib_version 0 and table cprea: Concept no match
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name cprea with GRIB version GRIB2 and table ecmf
# ECCODES ERROR   :  Please check the Parameter Database 'https://codes.ecmwf.int/grib/param-db/'
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var160143, shortname is cprea
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var160143 find eccodes shortname cprea, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for cprea: {'paramId': '160143', 'long_name': 'Convective precipitation', 'units': 'kg m**-2 s**-1', 'shortName': 'cprea', 'cfVarName': 'cprea'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> While fixing variable cprea, no match found with sources [143, 160143, 'cp', 'prc']
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var232, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var232
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name ie with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var232, shortname is ie
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var232 find eccodes shortname ie, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for ie: {'paramId': '232', 'long_name': 'Instantaneous moisture flux', 'units': 'kg m**-2 s**-1', 'shortName': 'ie', 'cfVarName': 'ie'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: ie
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: mer
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: ie
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> ie: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var229, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var229
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name iews with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var229, shortname is iews
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var229 find eccodes shortname iews, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for iews: {'paramId': '229', 'long_name': 'Instantaneous eastward turbulent surface stress', 'units': 'N m**-2', 'shortName': 'iews', 'cfVarName': 'iews'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: iews
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: metss
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: iews
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> iews: converting units N m**-2 --> N m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var230, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var230
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name inss with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var230, shortname is inss
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var230 find eccodes shortname inss, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for inss: {'paramId': '230', 'long_name': 'Instantaneous northward turbulent surface stress', 'units': 'N m**-2', 'shortName': 'inss', 'cfVarName': 'inss'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: inss
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: mntss
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: inss
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> inss: converting units N m**-2 --> N m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var231, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var231
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name ishf with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var231, shortname is ishf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var231 find eccodes shortname ishf, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for ishf: {'paramId': '231', 'long_name': 'Instantaneous surface sensible heat net flux', 'units': 'W m**-2', 'shortName': 'ishf', 'cfVarName': 'ishf'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: ishf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: msshf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: ishf
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> ishf: converting units W m**-2 --> W m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260050, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260050
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name lsprate with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260050, shortname is lsprate
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260050 find eccodes shortname lsprate, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for lsprate: {'paramId': '260050', 'long_name': 'Large scale precipitation rate', 'units': 'kg m**-2 s**-1', 'shortName': 'lsprate', 'cfVarName': 'lsprate'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> While fixing variable lsprate, no match found with sources [142, 260050, 'lsp', 'prlr']
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260097, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260097
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name sdlwrf with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260097, shortname is sdlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260097 find eccodes shortname sdlwrf, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for sdlwrf: {'paramId': '260097', 'long_name': 'Surface downward long-wave radiation flux', 'units': 'W m**-2', 'shortName': 'sdlwrf', 'cfVarName': 'sdlwrf'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: sdlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: msdwlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: sdlwrf
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> sdlwrf: converting units W m**-2 --> W m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260087, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260087
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name sdswrf with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260087, shortname is sdswrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260087 find eccodes shortname sdswrf, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for sdswrf: {'paramId': '260087', 'long_name': 'Surface downward short-wave radiation flux', 'units': 'W m**-2', 'shortName': 'sdswrf', 'cfVarName': 'sdswrf'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: sdswrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: msdwswrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: sdswrf
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> sdswrf: converting units W m**-2 --> W m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260002, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260002
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name slhtf with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260002, shortname is slhtf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260002 find eccodes shortname slhtf, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for slhtf: {'paramId': '260002', 'long_name': 'Surface latent heat net flux', 'units': 'W m**-2', 'shortName': 'slhtf', 'cfVarName': 'slhtf'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: slhtf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: mslhf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: slhtf
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> slhtf: converting units W m**-2 --> W m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260099, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260099
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name snlwrf with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260099, shortname is snlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260099 find eccodes shortname snlwrf, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for snlwrf: {'paramId': '260099', 'long_name': 'Surface net long-wave radiation flux', 'units': 'W m**-2', 'shortName': 'snlwrf', 'cfVarName': 'snlwrf'}
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of fixer var: snlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of data source var: msnlwrf
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Name of target var: snlwrf
# 2025-07-21 15:12:35 :: Fixer :: INFO     -> snlwrf: converting units W m**-2 --> W m**-2
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260100, looking for attributes
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var260100
# 2025-07-21 15:12:35 :: eccodes :: DEBUG    -> Trying short name snlwrfcs with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib variable var260100, shortname is snlwrfcs
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> For grib variable var260100 find eccodes shortname snlwrfcs, replacing it
# 2025-07-21 15:12:35 :: Fixer :: DEBUG    -> Grib attributes for snlwrfcs: {'paramId': '260100', 'long_name': 'Surface net long-wave radiation flux, clear sky', 'units': 'W m**-2', 'shortName': 'snlwrfcs', 'cfVarName': 'snlwrfcs'}
# ...
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262507, shortname is wo
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262507 find eccodes shortname wo, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for wo: {'paramId': '262507', 'long_name': 'Upward sea water velocity', 'units': 'm s**-1', 'shortName': 'wo', 'cfVarName': 'wo'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable wo, no match found with sources [262507, 263507, 'avg_wo', 'wo']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262001, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262001
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name siconc with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262001, shortname is siconc
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262001 find eccodes shortname siconc, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for siconc: {'paramId': '262001', 'long_name': 'Sea ice area fraction', 'units': 'Fraction', 'shortName': 'siconc', 'cfVarName': 'siconc'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Name of fixer var: siconc
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Name of data source var: CI
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Name of target var: siconc
# 2025-07-21 15:12:40 :: Fixer :: INFO     -> siconc: converting units (0 - 1) --> Fraction
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262002, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262002
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name sisnthick with GRIB version GRIB2 and table 0
# ECCODES ERROR   :  concept: no match for shortName=sisnthick
# ECCODES ERROR   :  concept: input handle edition=2, centre=0
# ECCODES ERROR   :  Please check the Parameter Database 'https://codes.ecmwf.int/grib/param-db/'
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Failed guessing for shortName GRIB2, grib_version 0 and table sisnthick: Concept no match
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name sisnthick with GRIB version GRIB2 and table ecmf
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262002, shortname is sisnthick
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262002 find eccodes shortname sisnthick, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for sisnthick: {'paramId': '262002', 'long_name': 'Snow thickness over sea ice', 'units': 'm', 'shortName': 'sisnthick', 'cfVarName': 'sisnthick'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable sisnthick, no match found with sources [262002, 263002, 'sisnthick', 'avg_sisnthick']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262000, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262000
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name sithick with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262000, shortname is sithick
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262000 find eccodes shortname sithick, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for sithick: {'paramId': '262000', 'long_name': 'Sea ice thickness', 'units': 'm', 'shortName': 'sithick', 'cfVarName': 'sithick'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable sithick, no match found with sources [262000, 263000, 'sit', 'm_ice', 'avg_sithick', 'sithick', 'sithic']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262003, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262003
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name siue with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262003, shortname is siue
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262003 find eccodes shortname siue, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for siue: {'paramId': '262003', 'long_name': 'Eastward sea ice velocity', 'units': 'm s**-1', 'shortName': 'siue', 'cfVarName': 'siue'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable siue, no match found with sources [262003, 263003, 'siue', 'uice', 'avg_siue', 'siu']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262004, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262004
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name sivn with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262004, shortname is sivn
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262004 find eccodes shortname sivn, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for sivn: {'paramId': '262004', 'long_name': 'Northward sea ice velocity', 'units': 'm s**-1', 'shortName': 'sivn', 'cfVarName': 'sivn'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable sivn, no match found with sources [262004, 263004, 'sivn', 'vice', 'avg_sivn', 'siv']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262008, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262008
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name sivol with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262008, shortname is sivol
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262008 find eccodes shortname sivol, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for sivol: {'paramId': '262008', 'long_name': 'Sea ice volume per unit area', 'units': 'm**3 m**-2', 'shortName': 'sivol', 'cfVarName': 'sivol'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable sivol, no match found with sources [262008, 263008, 'sivol', 'avg_sivol', 'sivolu']
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262009, looking for attributes
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Input is a variable name, extracting short name from: var262009
# 2025-07-21 15:12:40 :: eccodes :: DEBUG    -> Trying short name snvol with GRIB version GRIB2 and table 0
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib variable var262009, shortname is snvol
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> For grib variable var262009 find eccodes shortname snvol, replacing it
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> Grib attributes for snvol: {'paramId': '262009', 'long_name': 'Snow volume over sea ice per unit area', 'units': 'm**3 m**-2', 'shortName': 'snvol', 'cfVarName': 'snvol'}
# 2025-07-21 15:12:40 :: Fixer :: DEBUG    -> While fixing variable snvol, no match found with sources [262009, 263009, 'snvol', 'avg_snvol']
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> 2t: org_units is K, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> ie: org_units is m/day, tgt_units is kg m**-2 s**-1
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for ie
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> hcc: org_units is (0 - 1), tgt_units is %
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for hcc
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> lcc: org_units is (0 - 1), tgt_units is %
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for lcc
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> msl: org_units is Pa, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> mcc: org_units is (0 - 1), tgt_units is %
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for mcc
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> siconc: org_units is (0 - 1), tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tos: org_units is K, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> q: org_units is kg kg**-1, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> slhtf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for slhtf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> snswrfcs: org_units is W m**-2, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> snswrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for snswrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> snlwrfcs: org_units is W m**-2, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> snlwrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for snlwrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> ishf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for ishf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> sdswrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for sdswrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> sdlwrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for sdlwrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> t: org_units is K, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tnswrfcs: org_units is W m**-2, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tnswrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for tnswrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tnlwrfcs: org_units is W m**-2, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tnlwrf: org_units is J m**-2 day**-1, tgt_units is W m**-2
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for tnlwrf
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tcc: org_units is (0 - 1), tgt_units is %
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for tcc
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> tprate: org_units is m/day, tgt_units is kg m**-2 s**-1
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> Applying unit fixes for tprate
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> u: org_units is m s**-1, tgt_units is None
# 2025-07-21 15:12:40 :: FixerOperator :: DEBUG    -> v: org_units is m s**-1, tgt_units is None
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: time
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> time
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lon
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> longitude
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: lat
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> latitude
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> Identifying coordinate: plev
# 2025-07-21 15:12:40 :: CoordIdentifier :: DEBUG    -> isobaric
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Loading data model from /users/caprioli/.aqua/data_model/aqua.yaml
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Analysing coordinate: isobaric
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-07-21 15:12:40 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-07-21 15:12:40 :: CoordTransator :: DEBUG    -> time unit not found in target data model. Disabling unit conversion.
# 2025-07-21 15:12:40 :: CoordTransator :: DEBUG    -> Adding attribute long_name to coordinate time
# 2025-07-21 15:12:40 :: Global Biases :: INFO     -> Evaluating formula: tnlwrf+tnswrf
# 2025-07-21 15:12:40 :: EvaluateFormula :: DEBUG    -> Evaluating formula: tnlwrf+tnswrf
# 2025-07-21 15:12:40 :: EvaluateFormula :: DEBUG    -> Evaluated formula: tnlwrf+tnswrf, name: tnr, long name: Top net radiation
# 2025-07-21 15:12:40 :: Global Biases :: INFO     -> Computing climatology for variable tnr.
# 2025-07-21 15:12:40 :: Global Biases :: INFO     -> Plotting global biases.
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Updating the log_level to DEBUG
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> AQUA installation found in /users/caprioli/.aqua
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Configuration file found in /users/caprioli/.aqua/config-aqua.yaml
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Catalog found in /users/caprioli/.aqua/config-aqua.yaml file are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Available catalogs are ['ci', 'climatedt-phase1', 'climatedt-o25.1', 'obs']
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Default catalog will be ci
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Catalog file is /users/caprioli/.aqua/catalogs/ci/catalog.yaml
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Machine file is /users/caprioli/.aqua/catalogs/ci/machine.yaml
# 2025-07-21 15:12:49 :: ConfigPath :: DEBUG    -> Machine found in configuration file, set to lumi
# 2025-07-21 15:12:49 :: ConfigStyle :: DEBUG    -> Style file: /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:12:49 :: ConfigStyle :: DEBUG    -> Setting style aqua from file /users/caprioli/.aqua/styles/aqua.mplstyle
# 2025-07-21 15:12:49 :: plot_single_map :: DEBUG    -> Loading data in memory
# 2025-07-21 15:12:54 :: plot_single_map :: DEBUG    -> Adding cyclic longitude
# 2025-07-21 15:12:54 :: plot_single_map :: DEBUG    -> Setting vmin to -49.12733732083627, vmax to 49.12733732083627
# 2025-07-21 15:13:00 :: plot_single_map :: DEBUG    -> Adding coastlines
# 2025-07-21 15:13:00 :: cbar get label :: DEBUG    -> Using Top net radiation as colorbar label
# 2025-07-21 15:13:00 :: cbar get label :: DEBUG    -> Adding units to colorbar label
# 2025-07-21 15:13:00 :: plot_single_map :: DEBUG    -> Setting colorbar label to Top net radiation [W m**-2]
# 2025-07-21 15:13:00 :: plot_single_map :: DEBUG    -> Setting colorbar ticks to be symmetrical
# 2025-07-21 15:13:00 :: set map title :: DEBUG    -> Using Top net radiation [W m**-2] IFS-NEMO historical-1990 as map title
# 2025-07-21 15:13:00 :: plot_single_map :: DEBUG    -> Setting title to Top net radiation [W m**-2] IFS-NEMO historical-1990
# 2025-07-21 15:13:01 :: plot_single_map :: DEBUG    -> Returning figure and axes
# 2025-07-21 15:13:01 :: plot_single_map_diff :: DEBUG    -> Plotting the map
# 2025-07-21 15:13:01 :: plot_single_map_diff :: DEBUG    -> Adding cyclic longitude to the difference map
# 2025-07-21 15:13:01 :: plot_single_map_diff :: DEBUG    -> Plotting the map as contour
# 2025-07-21 15:13:01 :: plot_single_map_diff :: DEBUG    -> Setting contour vmin to -132.39353518612035, vmax to 106.64593159219103
# 2025-07-21 15:13:01 :: plot_single_map_diff :: DEBUG    -> Setting title to Global bias of Top net radiation for IFS-NEMO historical-1990
# relative to ERA5 climatology
