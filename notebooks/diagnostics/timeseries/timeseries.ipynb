# %% [markdown]
# # Timeseries
#
# This notebook shows how to use the timeseries diagnostic. Here we focus on the `Timeseries` for the single model evaluation and the `PlotTimeseries` for the multi model plots.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.timeseries import Timeseries
# Out:
# /LUMI_TYKKY_e0MDUMK/miniforge/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# We set the `Timeseries` for a model and ERA5, with two different class instances.

# %%
dataset_dict = {'catalog': 'climatedt-phase1',
                'model': 'ICON',
                'exp': 'historical-1990',
                'source': 'lra-r100-monthly'}
obs_dict = {'catalog': 'obs',
            'model': 'ERA5',
            'exp': 'era5',
            'source': 'monthly',
            'std_startdate': '1990-01-01',
            'std_enddate': '1999-12-31'}
common_dict = {'startdate': '1990-01-01',
               'enddate': '1999-12-31',
               'loglevel': 'info'}

# %%
ts_dataset = Timeseries(**dataset_dict, **common_dict)
# Out:
# 2025-08-28 13:31:35 :: Timeseries :: INFO     -> No region provided, using lon_limits: None, lat_limits: None

# %%
run_dict = {'var': '2t',
            'units': 'degC'}

# %%
ts_dataset.run(**run_dict)
# Out:
# 2025-08-28 13:31:38 :: Timeseries :: INFO     -> Running Timeseries for 2t
# 2025-08-28 13:31:38 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-08-28 13:31:38 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-08-28 13:31:38 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-08-28 13:31:38 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-08-28 13:31:39 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-08-28 13:31:39 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-08-28 13:31:39 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-08-28 13:32:35 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-08-28 13:32:35 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-08-28 13:32:35 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-08-28 13:32:35 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-08-28 13:32:35 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-08-28 13:32:35 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:32:35 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-08-28 13:32:35 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2025-08-28 13:32:35 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2025-08-28 13:32:35 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:32:36 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-08-28 13:32:36 :: Timeseries :: INFO     -> Computing monthly mean
# 2025-08-28 13:32:36 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:36 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:32:36 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:36 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:32:36 :: Timeseries :: INFO     -> Saving monthly data for timeseries to netcdf in ./
# 2025-08-28 13:32:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:37 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.climatedt-phase1.ICON.historical-1990.r1.2t.monthly.nc
# 2025-08-28 13:32:37 :: Timeseries :: INFO     -> Computing annual mean
# 2025-08-28 13:32:37 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:37 :: TimStat :: INFO     -> Resampling to YS frequency and computing mean...
# 2025-08-28 13:32:37 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:37 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2025-08-28 13:32:37 :: Timeseries :: INFO     -> Extending back the start date from 1990-07-01 00:00:00 to 1990-01-01 00:00:00
# 2025-08-28 13:32:37 :: Timeseries :: INFO     -> Extending the end date from 1999-07-31 23:59:59 to 1999-12-31 23:59:59
# 2025-08-28 13:32:37 :: Timeseries :: INFO     -> Saving annual data for timeseries to netcdf in ./
# 2025-08-28 13:32:37 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:37 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.climatedt-phase1.ICON.historical-1990.r1.2t.annual.nc

# %%
ts_obs = Timeseries(**obs_dict, **common_dict)
ts_obs.run(**run_dict, std=True)
# Out:
# 2025-08-28 13:32:42 :: Timeseries :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-08-28 13:32:42 :: Timeseries :: INFO     -> Running Timeseries for 2t
# 2025-08-28 13:32:42 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-08-28 13:32:42 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-08-28 13:32:42 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-08-28 13:32:42 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-08-28 13:32:42 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-08-28 13:32:42 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-08-28 13:32:42 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_era5-r025s.nc.
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:32:42 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-08-28 13:32:42 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2025-08-28 13:32:44 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2025-08-28 13:32:44 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:32:44 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-08-28 13:32:44 :: Timeseries :: INFO     -> Computing monthly mean
# 2025-08-28 13:32:44 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:44 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:32:44 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:44 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:32:45 :: Timeseries :: INFO     -> Computing monthly standard deviation
# 2025-08-28 13:32:45 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:45 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:32:45 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:45 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:32:45 :: Timeseries :: INFO     -> Saving monthly data for timeseries to netcdf in ./
# 2025-08-28 13:32:45 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:49 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.obs.ERA5.era5.r1.2t.monthly.nc
# 2025-08-28 13:32:49 :: Timeseries :: INFO     -> Saving monthly data for timeseries to netcdf in ./
# 2025-08-28 13:32:49 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:52 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.obs.ERA5.era5.r1.2t.monthly.std.nc
# 2025-08-28 13:32:52 :: Timeseries :: INFO     -> Computing annual mean
# 2025-08-28 13:32:52 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:52 :: TimStat :: INFO     -> Resampling to YS frequency and computing mean...
# 2025-08-28 13:32:52 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:52 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2025-08-28 13:32:52 :: Timeseries :: INFO     -> Extending back the start date from 1990-07-01 00:00:00 to 1990-01-01 00:00:00
# 2025-08-28 13:32:52 :: Timeseries :: INFO     -> Extending the end date from 1999-07-31 23:59:59 to 1999-12-31 23:59:59
# 2025-08-28 13:32:52 :: Timeseries :: INFO     -> Computing annual standard deviation
# 2025-08-28 13:32:52 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:32:52 :: TimStat :: INFO     -> Resampling to YS frequency and computing mean...
# 2025-08-28 13:32:52 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:32:52 :: timmean_chunk_completeness :: INFO     -> 10 chunks from 1990-01-01 00:00:00 to 1999-01-01 00:00:00 at YS frequency to be analysed...
# 2025-08-28 13:32:52 :: Timeseries :: INFO     -> Saving annual data for timeseries to netcdf in ./
# 2025-08-28 13:32:52 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:55 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.obs.ERA5.era5.r1.2t.annual.nc
# 2025-08-28 13:32:55 :: Timeseries :: INFO     -> Saving annual data for timeseries to netcdf in ./
# 2025-08-28 13:32:55 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:32:58 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/timeseries.timeseries.obs.ERA5.era5.r1.2t.annual.std.nc

# %%
from aqua.diagnostics.timeseries import PlotTimeseries

# %%
ts_obs.monthly
# Out:
# <xarray.DataArray '2t' (time: 120)> Size: 960B
# dask.array<where, shape=(120,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 960B 1990-01-16T12:00:00 ... 1999-12-16T12...
# Attributes: (12/24)
#     long_name:           2 metre temperature
#     units:               degC
#     code:                167
#     table:               128
#     history:             \n2025-06-19 11:35:35 AQUA💧: Variable renamed 2t fro...
#     paramId:             167
#     ...                  ...
#     exp:                 era5
#     var:                 2t
#     freq:                monthly
#     region:              None
#     timestamp:           2025-06-19 11:35:36
#     aqua_version:        0.16.0-alpha

# %%
plot_dict = {'monthly_data': ts_dataset.monthly,
             'annual_data': ts_dataset.annual,
             'ref_monthly_data': ts_obs.monthly,
             'ref_annual_data': ts_obs.annual,
             'std_monthly_data': ts_obs.std_monthly,
             'std_annual_data': ts_obs.std_annual,
             'loglevel': 'INFO'}

# %%
plot = PlotTimeseries(**plot_dict)
data_labels = plot.set_data_labels()
ref_labels = plot.set_ref_label()
desc = plot.set_description()
title = plot.set_title()
fig, _ = plot.plot_timeseries(data_labels=data_labels, ref_label=ref_labels, title=title)
plot.save_plot(fig=fig, description=desc)
# Out:
# 2025-08-28 13:37:28 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-08-28 13:37:28 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/timeseries.timeseries.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
# 2025-08-28 13:37:28 :: OutputSaver :: INFO     -> Saved PNG: ./png/timeseries.timeseries.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
