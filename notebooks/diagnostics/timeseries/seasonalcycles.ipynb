# %% [markdown]
# # Seasonal cycles
#
# This notebook shows how to use the seasonal cycles diagnostic. Here we focus on the `SeasonalCycles` for the single model evaluation and the `PlotSeasonalCycles` for the multi model plots.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.timeseries import SeasonalCycles
# Out:
# /LUMI_TYKKY_e0MDUMK/miniforge/envs/env1/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
dataset_dict = {'catalog': 'climatedt-phase1',
                'model': 'ICON',
                'exp': 'historical-1990',
                'source': 'lra-r100-monthly'}
obs_dict = {'catalog': 'obs',
            'model': 'ERA5',
            'exp': 'era5',
            'source': 'monthly',
            'std_startdate': '1990-01-01',
            'std_enddate': '1999-12-31'}
common_dict = {'startdate': '1990-01-01',
               'enddate': '1999-12-31',
               'loglevel': 'info'}

# %%
sc_dataset = SeasonalCycles(**dataset_dict, **common_dict)
# Out:
# 2025-08-28 13:38:50 :: Seasonalcycles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None

# %%
run_dict = {'var': '2t',
            'units': 'degC'}

# %%
sc_dataset.run(**run_dict)
# Out:
# 2025-08-28 13:38:50 :: Seasonalcycles :: INFO     -> Running SeasonalCycles for 2t
# 2025-08-28 13:38:50 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2025-08-28 13:38:50 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-08-28 13:38:50 :: Fixer :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2025-08-28 13:38:50 :: Fixer :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2025-08-28 13:38:50 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2025-08-28 13:38:50 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2025-08-28 13:38:50 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2025-08-28 13:39:11 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-08-28 13:39:11 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2025-08-28 13:39:11 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2025-08-28 13:39:11 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2025-08-28 13:39:11 :: Regridder :: INFO     -> Grid name: lon-lat
# 2025-08-28 13:39:11 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:39:11 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-08-28 13:39:11 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2025-08-28 13:39:11 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2025-08-28 13:39:12 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:39:12 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-08-28 13:39:12 :: Seasonalcycles :: INFO     -> Computing the seasonal cycles
# 2025-08-28 13:39:12 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:39:12 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:39:12 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:39:12 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:39:12 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2025-08-28 13:39:12 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:39:12 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.2t.monthly.nc

# %%
sc_obs = SeasonalCycles(**obs_dict, **common_dict)
sc_obs.run(**run_dict, std=True)
# Out:
# 2025-08-28 13:39:12 :: Seasonalcycles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2025-08-28 13:39:12 :: Seasonalcycles :: INFO     -> Running SeasonalCycles for 2t
# 2025-08-28 13:39:12 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2025-08-28 13:39:13 :: Fixer :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2025-08-28 13:39:13 :: Fixer :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2025-08-28 13:39:13 :: Fixer :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2025-08-28 13:39:13 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2025-08-28 13:39:13 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2025-08-28 13:39:13 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/areas/cell_area_era5-r025s.nc.
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Coordinate time not found in source coordinates.
# 2025-08-28 13:39:13 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2025-08-28 13:39:13 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2025-08-28 13:39:13 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Grid type: Regular
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Target data model: aqua
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Loading data model from /users/mattnuri/.aqua/data_model/aqua.yaml
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Analysing coordinate: latitude
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Reversing coordinate lat from decreasing to increasing
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Analysing coordinate: longitude
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Coordinate depth not found in source coordinates.
# 2025-08-28 13:39:13 :: CoordTransator :: INFO     -> Analysing coordinate: time
# 2025-08-28 13:39:13 :: Seasonalcycles :: INFO     -> Computing monthly standard deviation
# 2025-08-28 13:39:14 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:39:14 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:39:14 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:39:14 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:39:14 :: Seasonalcycles :: INFO     -> Computing the seasonal cycles
# 2025-08-28 13:39:14 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2025-08-28 13:39:14 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2025-08-28 13:39:14 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2025-08-28 13:39:14 :: timmean_chunk_completeness :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed...
# 2025-08-28 13:39:14 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2025-08-28 13:39:14 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:39:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.obs.ERA5.era5.r1.2t.monthly.nc
# 2025-08-28 13:39:17 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2025-08-28 13:39:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2025-08-28 13:39:20 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.obs.ERA5.era5.r1.2t.monthly.std.nc

# %%
from aqua.diagnostics.timeseries import PlotSeasonalCycles

# %%
plot_dict = {'monthly_data': sc_dataset.monthly,
             'ref_monthly_data': sc_obs.monthly,
             'std_monthly_data': sc_obs.std_monthly,
             'loglevel': 'INFO'}

# %%
plot = PlotSeasonalCycles(**plot_dict)
data_labels = plot.set_data_labels()
ref_labels = plot.set_ref_label()
desc = plot.set_description()
title = plot.set_title()
fig, _ = plot.plot_seasonalcycles(data_labels=data_labels, ref_label=ref_labels, title=title)
plot.save_plot(fig=fig, description=desc)
# Out:
# 2025-08-28 13:40:17 :: create_folder :: INFO     -> Folder ./png already exists
# 2025-08-28 13:40:18 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
# 2025-08-28 13:40:18 :: OutputSaver :: INFO     -> Saved PNG: ./png/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
